# %% [markdown]
# # Create Term - Document Matrix

# %%
from pymongo import MongoClient, errors
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from concurrent.futures import ThreadPoolExecutor
import threading
import logging
import re
from bson import ObjectId

# %% [markdown]
# ### Checking the MongoDB Connection.
#
# #### Source Connection will be the collection containing the extracted and cleaned texts from the transcript documents.
# #### Term Document Collection will be the collection used to store the Term Document Frequencies.

# %%
client = MongoClient("localhost", 27017)

# %%
db = client['transcripts']
collection_name = db['complete_documents']

# %% [markdown]
# ### Creating Term Document Frequencies
#
# The term - document frequencies will be evaluated for the extracted and cleaned texts from the transcript documents. This text is stored in teh 'complete_transcripts' collection. The function will evaluated the Term - Document frequencies from 'File Name' and 'Cleaned Text' available in this collection. The evaluated Term - Frequencies are then validated for count more than 1 (to eliminate the terms with 0 frequencies), and then the filtered terms with frequencies more than 1 are stored in a separate collection 'term_document_matrix_transcript'.

# %%
logging.basicConfig(level=logging.INFO)

def update_tdm_in_mongodb(db_name, collection_name, dept_db_name, dept_collection_name, keywords_db_name, keywords_collection_name, min_term_count=1, uri="mongodb://localhost:27017/"):
    try:
        # Connect to MongoDB
        client = MongoClient(uri)
        db = client[db_name]
        collection = db[collection_name]

        # Fetch department names from the department collection
        dept_db = client[dept_db_name]
        dept_collection = dept_db[dept_collection_name]
        department_names = [dept['dept_name'].lower() for dept in dept_collection.find()]

        # Fetch keywords from the keywords collection
        keywords_db = client[keywords_db_name]
        keywords_collection = keywords_db[keywords_collection_name]
        keyword_phrases = [kw['Relevant Topics'].lower() for kw in keywords_collection.find()]

        # Combine department names and keyword phrases
        combined_terms = department_names + keyword_phrases

        # Create a regex pattern to match combined terms
        combined_pattern = re.compile(r'\b(' + '|'.join(re.escape(term) for term in combined_terms) + r')\b', re.IGNORECASE)

        # Custom tokenizer to handle combined terms
        def custom_tokenizer(text):
            text = text.lower()  # Convert text to lowercase
            # Replace combined terms with a single token
            text = combined_pattern.sub(lambda match: match.group(0).replace(' ', '_').replace('(', '').replace(')', ''), text)
            # Use a regex pattern that includes special characters, numbers, and apostrophes
            return re.findall(r'\b[\w\-_\'\(\)]+\b', text)

        # Initialize the CountVectorizer with the custom tokenizer
        vectorizer = CountVectorizer(tokenizer=custom_tokenizer)

        # Fetch all documents from the collection
        documents = list(collection.find())

        updated_ids = []

        for doc in documents:
            text = doc.get("Text", "")
            if text:
                # Create the term-document matrix
                X = vectorizer.fit_transform([text])
                terms = vectorizer.get_feature_names_out()
                frequencies = X.toarray().flatten()  # Get the first (and only) row of the array

                logging.info(f"Terms: {terms}")
                logging.info(f"Frequencies: {frequencies}")

                # Create a dictionary of terms with frequency higher than min_term_count
                term_doc_matrix = {terms[i]: int(frequencies[i]) for i in range(len(terms)) if frequencies[i] >= min_term_count}

                # Convert _id to ObjectId
                doc_id = ObjectId(str(doc["_id"]))

                # Update the document with the term-document matrix
                collection.update_one({"_id": doc_id}, {"$set": {"Term Document Matrix": term_doc_matrix}})
                updated_ids.append(doc_id)

        logging.info("Term-document matrices have been added to the collection.")
        logging.info("Updated document IDs:")
        for doc_id in updated_ids:
            logging.info(doc_id)

    except errors.PyMongoError as e:
        logging.error(f"MongoDB error: {e}")
    except Exception as e:
        logging.error(f"An error occurred: {e}")

# %%
db_name = 'transcripts'
dept_db_name = 'foodsystems'
collection_name = 'complete_documents'
dept_collection_name = 'departments_and_agencies'
keywords_db_name = 'foodsystems'
keywords_collection_name = 'keywords'
update_tdm_in_mongodb(db_name, collection_name, dept_db_name,dept_collection_name, keywords_db_name, keywords_collection_name, min_term_count=2)
# Out:
# C:\Users\0132499s\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# INFO:root:Terms: ['000' '01' '02' ... 'zolvix' 'zoom' 'éireann']
# INFO:root:Frequencies: [6 1 1 ... 1 1 1]
# INFO:root:Terms: ['000' '04' '1' ... 'éagmais' 'éireann' 'ó']
# INFO:root:Frequencies: [ 7  1 16 ...  1  1  3]
# INFO:root:Terms: ['0' '000' '1' ... 'zoom' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1  3 23 ...  1  1  1]
# INFO:root:Terms: ['000' '04' '05' ... 'you' 'zealand' 'éireann']
# INFO:root:Frequencies: [22  1  1 ...  2  1  1]
# INFO:root:Terms: ['000' '10' '100' ... 'your' 'éagmais' 'éireann']
# INFO:root:Frequencies: [7 8 4 ... 2 2 1]
# INFO:root:Terms: ['000' '015' '08' ... 'you' 'zolvix' 'éireann']
# INFO:root:Frequencies: [1 1 1 ... 8 1 1]
# INFO:root:Terms: ['000' '1' '100' ... 'your' 'zero' 'éireann']
# INFO:root:Frequencies: [3 4 3 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '074' ... 'you' 'young' 'éireann']
# INFO:root:Frequencies: [1 7 1 ... 1 8 1]
# INFO:root:Terms: ['000' '05' '06' ... 'your' 'zealand' 'éireann']
# INFO:root:Frequencies: [1 1 1 ... 1 1 1]
# INFO:root:Terms: ['000' '1' '10' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [44 14 22 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '07' ... 'zoom' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 5 20  1 ...  3  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [10  3  4 ... 12  1 23]
# INFO:root:Terms: ['0' '000' '1' ... 'you' 'young' 'éireann']
# INFO:root:Frequencies: [ 1  4 10 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'z' 'zero' 'éireann']
# INFO:root:Frequencies: [ 2  7 13 ...  1  4  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [21 10  3 ...  1  1  1]
# INFO:root:Terms: ['0-7-30' '000' '1' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2  7 20 ...  3  5  1]
# INFO:root:Terms: ['000' '1' '10' ... 'à' 'éireann' 'ó']
# INFO:root:Frequencies: [ 8 10  5 ...  1  1  6]
# INFO:root:Terms: ['000' '01' '03' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [10  1  1 ... 23  1 32]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [3 8 9 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2 24  9 ...  7  1  9]
# INFO:root:Terms: ['000' '1' '10' ... 'zoonotic' 'éireann' 'ó']
# INFO:root:Frequencies: [27 12  2 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'you' 'your' 'éireann']
# INFO:root:Frequencies: [ 2  9  1 ... 27  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zones' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 39 17 ...  1  1  1]
# INFO:root:Terms: ['0' '00' '000' ... 'young' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 1  1  9 ... 21  7  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zeitgeist' 'zero' 'éireann']
# INFO:root:Frequencies: [99  7  7 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zealand' 'zens' 'éireann']
# INFO:root:Frequencies: [3 8 7 ... 1 2 1]
# INFO:root:Terms: ['0' '000' '1' ... 'youth' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 1 37 23 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 3 50 21 ... 23  1 45]
# INFO:root:Terms: ['0' '000' '05' ... 'zimbabwe' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 2 19  1 ...  2  1  1]
# INFO:root:Terms: ['000' '07' '1' ... 'zealand' 'zens' 'éireann']
# INFO:root:Frequencies: [24  1 13 ...  2  1  1]
# INFO:root:Terms: ['000' '008' '1' ... 'z' 'zone' 'éireann']
# INFO:root:Frequencies: [50  2 16 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'you' 'árainn' 'éireann']
# INFO:root:Frequencies: [ 3  9 14 ...  4  2  1]
# INFO:root:Terms: ['000' '000s' '1' ... 'youtube' 'zoom' 'éireann']
# INFO:root:Frequencies: [6 2 3 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '08' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [ 2 62  1 ...  3  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 3 37 15 ... 13  1 23]
# INFO:root:Terms: ['000' '03' '1' ... 'yet' 'young' 'éireann']
# INFO:root:Frequencies: [7 1 7 ... 5 1 1]
# INFO:root:Terms: ['000' '07' '08' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [14  1  1 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '040' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2 23  1 ...  9  1 16]
# INFO:root:Terms: ['000' '08' '1' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [ 6  1 10 ...  4  1  1]
# INFO:root:Terms: ['0' '000' '0000' ... 'young' 'zero' 'éireann']
# INFO:root:Frequencies: [ 1 34  1 ...  2  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zen' 'zilian' 'éireann']
# INFO:root:Frequencies: [13  7  2 ...  1  1  1]
# INFO:root:Terms: ['000' '05' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [54  1 33 ...  2  1  2]
# INFO:root:Terms: ['0' '000' '04' ... 'zoned' 'zontal' 'éireann']
# INFO:root:Frequencies: [ 2 27  1 ...  1  1  5]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [15  3  3 ...  2  2  1]
# INFO:root:Terms: ['000' '1' '1-2' ... 'your' 'zealand' 'éireann']
# INFO:root:Frequencies: [25  9  1 ...  2  2  1]
# INFO:root:Terms: ['0' '0-6' '000' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [ 1  1 26 ...  4 11  1]
# INFO:root:Terms: ['000' '05' '1' ... 'young' 'younger' 'éireann']
# INFO:root:Frequencies: [18  2 13 ... 12  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2  5  1 ...  7  1 12]
# INFO:root:Terms: ['0' '000' '07' ... 'your' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2 35  1 ...  1  1 56]
# INFO:root:Terms: ['0' '000' '016' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 43  1 ...  3  1 10]
# INFO:root:Terms: ['0' '000' '1' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [ 3 11 20 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '098' ... 'zones' 'éagmais' 'éireann']
# INFO:root:Frequencies: [10 46  1 ...  2  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zero-grazing' 'éireann']
# INFO:root:Frequencies: [8 1 1 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'younger' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 4 17 14 ...  6  2  2]
# INFO:root:Terms: ['000' '069' '1' ... 'éireann' 'éisc' 'ó']
# INFO:root:Frequencies: [49  1 13 ...  1  1 38]
# INFO:root:Terms: ['0' '00' '000' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [2 1 5 ... 4 1 4]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'zero' 'éireann']
# INFO:root:Frequencies: [ 7 21 14 ...  2  1  1]
# INFO:root:Terms: ['000' '05' '06' ... 'your' 'zealand' 'éireann']
# INFO:root:Frequencies: [27  1  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '07' ... 'zero-hour' 'zoonotic' 'éireann']
# INFO:root:Frequencies: [2 7 1 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'yield' 'young' 'éireann']
# INFO:root:Frequencies: [ 2 34 52 ...  1 27  1]
# INFO:root:Terms: ['0' '000' '1' ... 'youth' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 1 40 16 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '000s' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2  6  1 ... 25  1  2]
# INFO:root:Terms: ['000' '02' '058' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [32  1  1 ...  2  2  5]
# INFO:root:Terms: ['000' '1' '10' ... 'young' 'éireann' 'être']
# INFO:root:Frequencies: [34 22 17 ...  1  1  1]
# INFO:root:Terms: ['000' '000-tonne' '05' ... 'you' 'zero' 'éireann']
# INFO:root:Frequencies: [2 1 1 ... 2 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'young' 'your' 'éireann']
# INFO:root:Frequencies: [ 2 16 10 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1 60 13 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '05' ... 'younger' 'your' 'éireann']
# INFO:root:Frequencies: [1 1 1 ... 3 1 1]
# INFO:root:Terms: ['0' '000' '06' ... 'zealand' 'éireann' 'údarás']
# INFO:root:Frequencies: [ 2 18  1 ...  3  1  2]
# INFO:root:Terms: ['000' '02' '1' ... 'you' 'young' 'éireann']
# INFO:root:Frequencies: [41  1 10 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 13  9 ...  3  1 10]
# INFO:root:Terms: ['0' '000' '06' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 22  3 ...  3  1  9]
# INFO:root:Terms: ['0' '000' '000-tonne' ... 'your' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 2 23  1 ...  1  3  1]
# INFO:root:Terms: ['0' '000' '05' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2 61  1 ...  3  1  2]
# INFO:root:Terms: ['0' '000' '1' ... 'yesterday' 'yield' 'éireann']
# INFO:root:Frequencies: [ 5 18 15 ...  1  1  1]
# INFO:root:Terms: ['000' '05' '093' ... 'zero' 'zero-interest' 'éireann']
# INFO:root:Frequencies: [36  4  1 ...  1  2  1]
# INFO:root:Terms: ['000' '1' '10' ... 'you' 'your' 'éireann']
# INFO:root:Frequencies: [ 8  5  1 ... 11  2  1]
# INFO:root:Terms: ['0' '000' '03' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [ 1 11  2 ...  3  1  8]
# INFO:root:Terms: ['0' '000' '1' ... 'your' 'yourself' 'éireann']
# INFO:root:Frequencies: [ 2 15  9 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '000-gallon' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [ 6 16  1 ...  3  2  1]
# INFO:root:Terms: ['000' '02' '03' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [6 1 1 ... 2 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'zealand' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 30 16 ... 17  1 11]
# INFO:root:Terms: ['000' '1' '10' ... 'youngster' 'youngsters' 'éireann']
# INFO:root:Frequencies: [37  5  2 ...  1  2  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 3 22 10 ...  6  1  8]
# INFO:root:Terms: ['0' '000' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2 21 32 ... 11  2 12]
# INFO:root:Terms: ['000' '06' '1' ... 'youngest' 'éireann' 'ó']
# INFO:root:Frequencies: [ 9  1 18 ...  1  2 22]
# INFO:root:Terms: ['000' '063' '1' ... 'áine' 'éireann' 'ór']
# INFO:root:Frequencies: [63  2 19 ...  1  2  1]
# INFO:root:Terms: ['0' '00' '000' ... 'áine' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1  1 87 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zoom' 'éireann']
# INFO:root:Frequencies: [21 29  1 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'zero' 'éireann']
# INFO:root:Frequencies: [ 4  4 12 ...  4  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'younger' 'your' 'éireann']
# INFO:root:Frequencies: [ 2 27 27 ...  1  8  1]
# INFO:root:Terms: ['000' '1' '10' ... 'z' 'zero' 'éireann']
# INFO:root:Frequencies: [13 17  1 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'youth' 'zone' 'éireann']
# INFO:root:Frequencies: [19 11  7 ...  3  2  1]
# INFO:root:Terms: ['000' '01' '03' ... 'zealand' 'éagmais' 'éireann']
# INFO:root:Frequencies: [14  1  1 ... 16  1  1]
# INFO:root:Terms: ['0' '000' '01' ... 'z' 'zone' 'éireann']
# INFO:root:Frequencies: [11 16  1 ...  1  1  1]
# INFO:root:Terms: ['000' '01' '023' ... 'your' 'z' 'éireann']
# INFO:root:Frequencies: [109   1   1 ...   5   1   3]
# INFO:root:Terms: ['0' '000' '000-odd' ... 'zone' 'éireann' 'être']
# INFO:root:Frequencies: [13 34  1 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zone' 'éireann' 'ó']
# INFO:root:Frequencies: [9 6 1 ... 1 1 1]
# INFO:root:Terms: ['000' '02' '06' ... 'young' 'younger' 'éireann']
# INFO:root:Frequencies: [40  1  1 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '100' ... 'zones' 'à' 'éireann']
# INFO:root:Frequencies: [26 17  4 ...  2  1  1]
# INFO:root:Terms: ['000' '08' '1' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [46  2 12 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '04' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2 21  2 ...  3  3  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'éagmais' 'éireann']
# INFO:root:Frequencies: [19 12  9 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [22 24  1 ...  6  3  1]
# INFO:root:Terms: ['000' '06' '1' ... 'zealand' 'éagmais' 'éireann']
# INFO:root:Frequencies: [91  1  7 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'zero' 'zero-carbon' 'éireann']
# INFO:root:Frequencies: [12 65  1 ...  5  1  1]
# INFO:root:Terms: ['000' '05' '1' ... 'youth' 'zero' 'éireann']
# INFO:root:Frequencies: [ 1  1 11 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'à' 'éireann']
# INFO:root:Frequencies: [1 7 3 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '09' ... 'zones' 'éagmais' 'éireann']
# INFO:root:Frequencies: [14 21  1 ...  1  1 14]
# INFO:root:Terms: ['000' '1' '10' ... 'youngest' 'your' 'éireann']
# INFO:root:Frequencies: [19  7  3 ...  1 11  1]
# INFO:root:Terms: ['000' '1' '10' ... 'yet' 'you' 'éireann']
# INFO:root:Frequencies: [10  4  3 ...  5  1  1]
# INFO:root:Terms: ['0' '000' '01' ... 'zero' 'zinc' 'éireann']
# INFO:root:Frequencies: [11 20  3 ... 26  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zones' 'éire' 'éireann']
# INFO:root:Frequencies: [18  6  4 ...  1  1 35]
# INFO:root:Terms: ['000' '000-cow' '03' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [11  1  1 ...  4  1  2]
# INFO:root:Terms: ['0' '000' '05' ... 'youth' 'zone' 'éireann']
# INFO:root:Frequencies: [ 1 90  1 ...  1  1  1]
# INFO:root:Terms: ['000' '09' '1' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [5 1 5 ... 4 1 1]
# INFO:root:Terms: ['0' '000' '0000' ... 'z' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 1 33  1 ...  1  1 22]
# INFO:root:Terms: ['000' '002' '07' ... 'young' 'your' 'éireann']
# INFO:root:Frequencies: [51  1  1 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'zone' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1 13  1 ...  3  1  1]
# INFO:root:Terms: ['000' '065' '1' ... 'yourself' 'z' 'éireann']
# INFO:root:Frequencies: [ 9  1 11 ...  1  1  1]
# INFO:root:Terms: ['000' '0284' '1' ... 'zero' 'zero-grazing' 'éireann']
# INFO:root:Frequencies: [27  1  7 ...  1  1  2]
# INFO:root:Terms: ['0' '000' '1' ... 'zones' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1 16 16 ...  3  1  1]
# INFO:root:Terms: ['000' '06' '1' ... 'zealand' 'zealanders' 'éireann']
# INFO:root:Frequencies: [19  1 31 ... 17  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'your' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 2 31 11 ...  2  1 11]
# INFO:root:Terms: ['000' '1' '100' ... 'your' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 5  3 10 ...  2  1  2]
# INFO:root:Terms: ['000' '03' '04' ... 'you' 'your' 'éireann']
# INFO:root:Frequencies: [3 1 1 ... 6 1 1]
# INFO:root:Terms: ['0' '000' '1' ... 'zealand' 'zealand-style' 'éireann']
# INFO:root:Frequencies: [ 2 14  4 ...  3  1  1]
# INFO:root:Terms: ['000' '015' '09' ... 'zealand' 'é' 'éireann']
# INFO:root:Frequencies: [8 3 1 ... 1 1 1]
# INFO:root:Terms: ['000' '081' '1' ... 'zones' 'é' 'éireann']
# INFO:root:Frequencies: [31  1 15 ...  5  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 1 26 21 ...  1  8  1]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'zoom' 'éireann']
# INFO:root:Frequencies: [14  6  3 ...  7  1  1]
# INFO:root:Terms: ['000' '044' '1' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [28  1 12 ... 47  1 53]
# INFO:root:Terms: ['0' '000' '01' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [1 9 1 ... 1 1 1]
# INFO:root:Terms: ['0' '000' '04' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [ 5 13  1 ...  5  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zones' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1 13 15 ...  2  1  5]
# INFO:root:Terms: ['0' '000' '03' ... 'your' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 1 16  1 ...  4  1  1]
# INFO:root:Terms: ['000' '01' '01-6072379' ... 'z' 'zero' 'éireann']
# INFO:root:Frequencies: [12  1  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [ 1 18 14 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'zealand' 'zespri' 'éireann']
# INFO:root:Frequencies: [ 1 24  1 ... 46  1  1]
# INFO:root:Terms: ['0' '000' '000-odd' ... 'zero-carbon' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 2 63  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '01' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [ 1 37  1 ...  1  1  2]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'éireann' 'ó']
# INFO:root:Frequencies: [79 27  8 ...  1  1  1]
# INFO:root:Terms: ['000' '04' '06' ... 'zfns' 'zinc' 'éireann']
# INFO:root:Frequencies: [14  1  1 ...  1  1  3]
# INFO:root:Terms: ['0' '000' '03' ... 'zealand' 'zone' 'éireann']
# INFO:root:Frequencies: [ 3 74  1 ...  2  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'younger' 'éireann' 'ó']
# INFO:root:Frequencies: [15 31  2 ...  1  2  1]
# INFO:root:Terms: ['000' '1' '10' ... 'young' 'z' 'éireann']
# INFO:root:Frequencies: [21  7 14 ...  1  1  1]
# INFO:root:Terms: ['000' '04' '1' ... 'young' 'younger' 'éireann']
# INFO:root:Frequencies: [13  1  8 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'you' 'young' 'éireann']
# INFO:root:Frequencies: [ 1 10 14 ...  1  4  1]
# INFO:root:Terms: ['000' '025' '036' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [25  1  1 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zone' 'éireann']
# INFO:root:Frequencies: [48 14 10 ...  2  1  1]
# INFO:root:Terms: ['000' '1' '1(b' ... 'zooming' 'éagmais' 'éireann']
# INFO:root:Frequencies: [28 31  1 ...  1  2  2]
# INFO:root:Terms: ['0' '000' '044' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 55  1 ... 12  1 13]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'zero' 'éireann']
# INFO:root:Frequencies: [25 34 10 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'yields' 'zealand' 'éireann']
# INFO:root:Frequencies: [ 2 15  9 ...  1  2  1]
# INFO:root:Terms: ['000' '030' '050' ... 'yet' 'you' 'éireann']
# INFO:root:Frequencies: [40  1  1 ...  2  2  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zoning' 'ár-nua' 'éireann']
# INFO:root:Frequencies: [ 7 26 12 ...  1  1  2]
# INFO:root:Terms: ['000' '07' '093' ... 'yet' 'you' 'éireann']
# INFO:root:Frequencies: [8 1 1 ... 2 1 1]
# INFO:root:Terms: ['000' '084' '1' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [44  1 15 ...  1  3  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zone' 'zones' 'éireann']
# INFO:root:Frequencies: [29 25  7 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '05' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 17  3 ...  1  2  1]
# INFO:root:Terms: ['000' '1' '10' ... 'ó' 'údaras' 'údarás']
# INFO:root:Frequencies: [24  6  4 ...  9  1  3]
# INFO:root:Terms: ['0' '000' '1' ... 'éireann' 'í' 'ó']
# INFO:root:Frequencies: [ 1 35 28 ...  1  1 10]
# INFO:root:Terms: ['000' '1' '10' ... 'áitiúil' 'éireann' 'ó']
# INFO:root:Frequencies: [ 5  3  1 ...  1  1 13]
# INFO:root:Terms: ['000' '1' '10' ... 'ó' 'ón' 'óstáin']
# INFO:root:Frequencies: [39 24  3 ...  3  1  1]
# INFO:root:Terms: ['0' '000' '087' ... 'young' 'zero' 'éireann']
# INFO:root:Frequencies: [ 1 13  1 ...  2  3  2]
# INFO:root:Terms: ['000' '1' '10' ... 'your' 'youth' 'éireann']
# INFO:root:Frequencies: [12 27  3 ...  1  1  1]
# INFO:root:Terms: ['000' '07' '1' ... 'zones' 'zoning' 'éireann']
# INFO:root:Frequencies: [15  1 10 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'yet' 'you' 'éireann']
# INFO:root:Frequencies: [ 2  7 14 ...  3  5  2]
# INFO:root:Terms: ['000' '1' '100' ... 'yesterday' 'you' 'éireann']
# INFO:root:Frequencies: [ 7  6 13 ...  1  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'à' 'éireann' 'ó']
# INFO:root:Frequencies: [ 8 10  5 ...  1  1  6]
# INFO:root:Terms: ['0' '000' '000mw' ... 'éamon' 'éireann' 'šefčovič']
# INFO:root:Frequencies: [ 2 35  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '02' ... 'zero' 'éireann' 'ó']
# INFO:root:Frequencies: [ 4 71  2 ... 10  1 57]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [ 7 35 28 ...  5  1 10]
# INFO:root:Terms: ['000' '050' '07' ... 'áine' 'éagmais' 'éireann']
# INFO:root:Frequencies: [26  1  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '01' ... 'zero' 'zero-carbon' 'éireann']
# INFO:root:Frequencies: [ 3 22  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [  2   4   9 ...   1 121   2]
# INFO:root:Terms: ['000' '09' '1' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [15  1 19 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '05' ... 'your' 'zero' 'éireann']
# INFO:root:Frequencies: [ 1 30  1 ...  1 10  1]
# INFO:root:Terms: ['0' '000' '07' ... 'zurich' 'zürich' 'éireann']
# INFO:root:Frequencies: [3 4 1 ... 1 1 3]
# INFO:root:Terms: ['0' '000' '1' ... 'zones' 'éagmais' 'éireann']
# INFO:root:Frequencies: [ 5 10 16 ...  3  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero-carbon' 'zone' 'éireann']
# INFO:root:Frequencies: [26  6  3 ...  1  1  4]
# INFO:root:Terms: ['0' '000' '1' ... 'zero-carbon' 'zimbabwe' 'éireann']
# INFO:root:Frequencies: [ 1  3 19 ...  2  1  9]
# INFO:root:Terms: ['0' '000' '1' ... 'zone' 'zooplankton' 'éireann']
# INFO:root:Frequencies: [ 2 31 23 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'zero-carbon' 'éireann']
# INFO:root:Frequencies: [2 6 3 ... 2 1 2]
# INFO:root:Terms: ['0' '000' '05' ... 'you' 'zens' 'éireann']
# INFO:root:Frequencies: [ 2 13  1 ...  2  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zimmer' 'éireann' 'ó']
# INFO:root:Frequencies: [ 7 17  3 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'your' 'zens' 'éireann']
# INFO:root:Frequencies: [ 2 17 13 ...  1  1  1]
# INFO:root:Terms: ['000' '04' '09' ... 'yet' 'young' 'éireann']
# INFO:root:Frequencies: [9 1 1 ... 6 1 1]
# INFO:root:Terms: ['0' '000' '05' ... 'zero' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 13  1 ... 12  1  2]
# INFO:root:Terms: ['0' '000' '01' ... 'zero' 'zevi' 'éireann']
# INFO:root:Frequencies: [ 1 25  1 ...  4  2  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zoned' 'zones' 'éireann']
# INFO:root:Frequencies: [30 20 10 ...  1  3  1]
# INFO:root:Terms: ['000' '07' '1' ... 'zero-carbon' 'éagmais' 'éireann']
# INFO:root:Frequencies: [26  1 17 ...  4  1  1]
# INFO:root:Terms: ['0-7-30' '000' '1' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2  7 20 ...  3  5  1]
# INFO:root:Terms: ['0' '00' '000' ... 'zero-sum' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1  2  2 ...  1  3 45]
# INFO:root:Terms: ['0' '08' '1' ... 'zero' 'éamon' 'éireann']
# INFO:root:Frequencies: [ 2  1 12 ... 11  2  2]
# INFO:root:Terms: ['1' '10' '10jeca' ... 'zealand' 'zero' 'éireann']
# INFO:root:Frequencies: [4 2 1 ... 4 4 1]
# INFO:root:Terms: ['0' '00' '000' ... 'zone' 'éireann' 'ó']
# INFO:root:Frequencies: [ 5  2 43 ...  1  2 39]
# INFO:root:Terms: ['000' '1' '10' ... 'éagmais' 'éireann' 'ó']
# INFO:root:Frequencies: [ 8  3  5 ...  1  2 10]
# INFO:root:Terms: ['0' '000' '066' ... 'zero' 'zones' 'éireann']
# INFO:root:Frequencies: [ 2 26  2 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '1' ... 'zero' 'zero-packaging' 'éireann']
# INFO:root:Frequencies: [ 2 17 10 ...  4  1  1]
# INFO:root:Terms: ['000' '1' '10' ... 'áine' 'éireann' 'ó']
# INFO:root:Frequencies: [10  4  2 ...  1  1 19]
# INFO:root:Terms: ['0' '000' '1' ... 'zealand' 'zones' 'éireann']
# INFO:root:Frequencies: [ 3 17 14 ...  3  1  1]
# INFO:root:Terms: ['00' '000' '07' ... 'zones' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2  2  1 ...  1  1 31]
# INFO:root:Terms: ['000' '04' '1' ... 'zoning' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2  1  7 ...  1  1 19]
# INFO:root:Terms: ['0' '000' '1' ... 'zevi' 'zone' 'éireann']
# INFO:root:Frequencies: [11 24 10 ...  2  2  1]
# INFO:root:Terms: ['0' '000' '1' ... 'youth' 'zero' 'éireann']
# INFO:root:Frequencies: [ 3 28 13 ...  1  6  1]
# INFO:root:Terms: ['000' '1' '10' ... 'zero' 'zon' 'éireann']
# INFO:root:Frequencies: [15 14  1 ...  7  1  1]
# INFO:root:Terms: ['000' '000-tonne' '1' ... 'zero-carbon' 'zero-emissions' 'éireann']
# INFO:root:Frequencies: [22  1 18 ...  1  2  1]
# INFO:root:Terms: ['08' '09' '1' ... 'your' 'éireann' 'éireann-screen']
# INFO:root:Frequencies: [1 1 9 ... 2 6 1]
# INFO:root:Terms: ['0' '000' '1' ... 'z' 'zero' 'éireann']
# INFO:root:Frequencies: [1 6 6 ... 1 7 1]
# INFO:root:Terms: ['000' '000-odd' '1' ... 'your' 'éire' 'éireann']
# INFO:root:Frequencies: [15  1 19 ...  1  3 25]
# INFO:root:Terms: ['0' '000' '1' ... 'zero-hour' 'éireann' 'ó']
# INFO:root:Frequencies: [ 2  5 32 ...  1  1  5]
# INFO:root:Terms: ['000' '1' '100' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 7  9  9 ...  7 12 17]
# INFO:root:Terms: ['000' '059' '1' ... 'yet' 'you' 'éireann']
# INFO:root:Frequencies: [22  1  7 ...  1  1  1]
# INFO:root:Terms: ['000' '01' '09' ... 'zero' 'éagmais' 'éireann']
# INFO:root:Frequencies: [8 1 1 ... 8 1 9]
# INFO:root:Terms: ['000' '02' '07' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [63 84 90 ... 42 11  2]
# INFO:root:Terms: ['000' '04' '1' ... 'éireann' 'ó' 'óglaigh']
# INFO:root:Frequencies: [11 26 10 ... 21 13  1]
# INFO:root:Terms: ['0' '00' '000' ... 'óglaigh' 'óige' 'úsáid']
# INFO:root:Frequencies: [ 1  2 30 ...  3  1  1]
# INFO:root:Terms: ['0' '000' '00100covid-19' ... 'éindí' 'éireann' 'ó']
# INFO:root:Frequencies: [ 3 49  1 ...  1 70 28]
# INFO:root:Terms: ['0' '000' '02' ... 'ábhar' 'éireann' 'ó']
# INFO:root:Frequencies: [  1  42 294 ...   1  67  13]
# INFO:root:Terms: ['0' '00' '000' ... 'éireann' 'éisteacht' 'ó']
# INFO:root:Frequencies: [ 4  1 24 ... 62  1 22]
# INFO:root:Terms: ['0' '000' '1' ... 'ó' 'ócáid' 'óige']
# INFO:root:Frequencies: [ 9 84 65 ... 58  1  1]
# INFO:root:Terms: ['0' '00' '000' ... 'ó' 'óglaigh' 'údarás']
# INFO:root:Frequencies: [ 6  1 92 ... 17  1  2]
# INFO:root:Terms: ['0' '000' '031' ... 'éireann' 'éis' 'ó']
# INFO:root:Frequencies: [ 35 104   1 ...  80   1  67]
# INFO:root:Terms: ['0' '000' '010' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 3 67  1 ... 42 68  4]
# INFO:root:Terms: ['0' '000' '023' ... 'ó' 'óglaigh' 'ón']
# INFO:root:Frequencies: [ 4 57  1 ... 33  4  4]
# INFO:root:Terms: ['000' '02' '033' ... 'údarás' 'úinéirí' 'úsáid']
# INFO:root:Frequencies: [64  3  1 ... 99  1 10]
# INFO:root:Terms: ['000' '05' '1' ... 'átha' 'é' 'éireann']
# INFO:root:Frequencies: [ 1 35  2 ...  1  1 25]
# INFO:root:Terms: ['0' '000' '022' ... 'úsáid' 'úsáidtear' 'šefčovič']
# INFO:root:Frequencies: [ 6 74  1 ...  3  2  2]
# INFO:root:Terms: ['0' '000' '004' ... 'é' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 78  1 ...  2 64 19]
# INFO:root:Terms: ['0' '00' '000' ... 'éireann' 'í' 'ó']
# INFO:root:Frequencies: [ 1  7 39 ... 89  2 19]
# INFO:root:Terms: ['000' '04' '05' ... 'ó' 'óglaigh' 'šefčovič']
# INFO:root:Frequencies: [ 83   2 603 ...  55   1   2]
# INFO:root:Terms: ['0' '000' '04' ... 'éireann' 'éisteacht' 'ó']
# INFO:root:Frequencies: [ 13  31 445 ...  81   1  55]
# INFO:root:Terms: ['0' '000' '000-5' ... 'éireann' 'ó' 'úsáid']
# INFO:root:Frequencies: [ 10  82   1 ... 104  95   1]
# INFO:root:Terms: ['0' '000' '000-pupil' ... 'údaráis' 'údarás' 'úsáid']
# INFO:root:Frequencies: [ 3 90  1 ...  2 21  7]
# INFO:root:Terms: ['0' '000' '007' ... 'éireann' 'ó' 'óglaigh']
# INFO:root:Frequencies: [ 5 36  1 ... 68 35  2]
# INFO:root:Terms: ['000' '000-person' '000-plus' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [63  1  1 ... 52 23  1]
# INFO:root:Terms: ['0' '000' '019' ... 'ón' 'údarás' 'úr']
# INFO:root:Frequencies: [  3 103   1 ...   5   2   1]
# INFO:root:Terms: ['0' '000' '0000' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 3 91  1 ... 76 27  2]
# INFO:root:Terms: ['0' '000' '020' ... 'í' 'ó' 'ón']
# INFO:root:Frequencies: [ 5 99  1 ...  1 32  9]
# INFO:root:Terms: ['0' '000' '010' ... 'éireann' 'éisteacht' 'ó']
# INFO:root:Frequencies: [ 3 93  1 ... 51  2 41]
# INFO:root:Terms: ['0' '000' '06' ... 'éis' 'ó' 'úinéirí']
# INFO:root:Frequencies: [ 1 70  1 ...  2 28  1]
# INFO:root:Terms: ['0' '000' '000s' ... 'óglaigh' 'ón' 'úis']
# INFO:root:Frequencies: [  8 193   1 ...   8   2   1]
# INFO:root:Terms: ['0' '000' '07' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [  3  64 459 ...  61  27   3]
# INFO:root:Terms: ['0' '000' '076' ... 'ó' 'ós' 'údarás']
# INFO:root:Frequencies: [ 3 71  1 ... 20  1  2]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ár' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 57  1 ...  1 43  4]
# INFO:root:Terms: ['0' '000' '02' ... 'óglaigh' 'ón' 'úcráin']
# INFO:root:Frequencies: [  3 119 539 ...   1   2   1]
# INFO:root:Terms: ['0' '000' '000-acre' ... 'ó' 'ón' 'úinéir']
# INFO:root:Frequencies: [ 2 44  1 ... 25  4  1]
# INFO:root:Terms: ['0' '000' '0100deputy' ... 'únag' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 2 64  1 ...  3  1  3]
# INFO:root:Terms: ['0' '000' '007' ... 'ó' 'óglaigh' 'úi']
# INFO:root:Frequencies: [ 7 39  1 ... 58  1  1]
# INFO:root:Terms: ['0' '000' '06' ... 'údaráis' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  1  65 429 ...   1   1   1]
# INFO:root:Terms: ['0' '000' '07' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [10 43  2 ... 73 38  1]
# INFO:root:Terms: ['000' '000-year' '1' ... 'údarás' 'úsáid' 'úsáidfear']
# INFO:root:Frequencies: [60  1 49 ...  3  4  1]
# INFO:root:Terms: ['0' '000' '0002' ... 'úinéireacht' 'úr' 'úsáid']
# INFO:root:Frequencies: [ 1 72  1 ...  2  1  2]
# INFO:root:Terms: ['0' '000' '04' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [  3  38 378 ...   1  70  18]
# INFO:root:Terms: ['0' '000' '000-pupil' ... 'ó' 'óg' 'údarás']
# INFO:root:Frequencies: [ 2 79  1 ... 37  1  2]
# INFO:root:Terms: ['0' '000' '05' ... 'ó' 'ócáid' 'ós']
# INFO:root:Frequencies: [ 5 94  1 ... 60  2  1]
# INFO:root:Terms: ['000' '00ceisteanna' '02' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [ 62   2 471 ...  34   2   1]
# INFO:root:Terms: ['000' '02' '036' ... 'éisteann' 'ó' 'úinéirí']
# INFO:root:Frequencies: [57  2  1 ...  1 50  1]
# INFO:root:Terms: ['0' '000' '06' ... 'ó' 'óige' 'údarás']
# INFO:root:Frequencies: [  4  59 408 ...  47   1   1]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 9 90  1 ... 13 66 18]
# INFO:root:Terms: ['0' '000' '01' ... 'ón' 'šefcovic' 'šefčovič']
# INFO:root:Frequencies: [  3  68 421 ...   2   1   1]
# INFO:root:Terms: ['0' '000' '03' ... 'ó' 'óg' 'ón']
# INFO:root:Frequencies: [ 4 41  1 ... 16  1  4]
# INFO:root:Terms: ['00' '000' '025' ... 'ón' 'úinéireacht' 'úsáideach']
# INFO:root:Frequencies: [ 1 93  1 ...  4  3  1]
# INFO:root:Terms: ['0' '000' '04' ... 'éireann' 'ísle' 'ó']
# INFO:root:Frequencies: [  4  95 328 ...  86   1  22]
# INFO:root:Terms: ['0' '000' '02' ... 'ó' 'óg' 'óirr']
# INFO:root:Frequencies: [  1  84 373 ...  29   1   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [ 4 55  2 ...  1 66 27]
# INFO:root:Terms: ['0' '000' '047' ... 'óg' 'óntaí' 'úsáid']
# INFO:root:Frequencies: [ 3 65  2 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '000-pupil' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [  2 105   1 ...  77  39   2]
# INFO:root:Terms: ['0' '000' '01' ... 'éis' 'ó' 'ón']
# INFO:root:Frequencies: [ 9 52  1 ...  1 15  2]
# INFO:root:Terms: ['0' '00' '000' ... 'í' 'ó' 'óga']
# INFO:root:Frequencies: [ 1  1 69 ...  1 10  2]
# INFO:root:Terms: ['000' '038' '06' ... 'í' 'ó' 'šefčovič']
# INFO:root:Frequencies: [ 65   1 377 ...   2  50   1]
# INFO:root:Terms: ['000' '03' '05' ... 'éire' 'éireann' 'óg']
# INFO:root:Frequencies: [ 47 321   1 ...   1  49   1]
# INFO:root:Terms: ['0' '000' '02' ... 'óige' 'óna' 'óstáin']
# INFO:root:Frequencies: [ 1 67  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '026' ... 'éireann' 'éis' 'ó']
# INFO:root:Frequencies: [13 72  1 ... 72  1 70]
# INFO:root:Terms: ['0' '000' '01' ... 'íoc' 'ó' 'úsáid']
# INFO:root:Frequencies: [ 1 89  2 ...  2 66  1]
# INFO:root:Terms: ['0' '000' '02' ... 'éireann' 'être' 'ó']
# INFO:root:Frequencies: [ 6 41  1 ... 81  1 33]
# INFO:root:Terms: ['0' '000' '050' ... 'éireann' 'ó' 'šefovi']
# INFO:root:Frequencies: [ 1 48  1 ... 88 16  4]
# INFO:root:Terms: ['0' '000' '007' ... 'éascú' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 67  2 ...  1 52 45]
# INFO:root:Terms: ['0' '000' '00100ceisteanna' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 9 80  1 ...  6 77 58]
# INFO:root:Terms: ['000' '004' '030' ... 'ómós' 'ón' 'úsáid']
# INFO:root:Frequencies: [56  1  1 ...  1  2  1]
# INFO:root:Terms: ['0' '00' '000' ... 'ísliú' 'ó' 'ón']
# INFO:root:Frequencies: [ 5  1 86 ...  1 17  1]
# INFO:root:Terms: ['0' '000' '005' ... 'éireann' 'ó' 'óg']
# INFO:root:Frequencies: [ 15 122   1 ...  74  16   1]
# INFO:root:Terms: ['0' '000' '000ha' ... 'údaráis' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  2 152   2 ...   4  15   1]
# INFO:root:Terms: ['0' '000' '03' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  3  42 476 ...   1  30   3]
# INFO:root:Terms: ['0' '000' '05' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  3  88 505 ...   2  80  18]
# INFO:root:Terms: ['0' '000' '012' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [ 1 66  1 ... 86 28  1]
# INFO:root:Terms: ['0' '000' '000-word' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [  6 166   1 ... 100   1   1]
# INFO:root:Terms: ['0' '000' '012' ... 'ó' 'óg' 'óga']
# INFO:root:Frequencies: [ 3 96  1 ... 18  1  1]
# INFO:root:Terms: ['0' '000' '048' ... 'éireann' 'ó' 'óglaigh']
# INFO:root:Frequencies: [ 6 59  1 ... 77 34  2]
# INFO:root:Terms: ['0' '000' '000-person' ... 'údaráis' 'údarás' 'úsáid']
# INFO:root:Frequencies: [ 6 40  1 ...  1  5  1]
# INFO:root:Terms: ['0' '000' '008' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  4 102   1 ...   6  83  67]
# INFO:root:Terms: ['0' '000' '018' ... 'éireann' 'í' 'ó']
# INFO:root:Frequencies: [ 2 49  1 ... 90  1 17]
# INFO:root:Terms: ['000' '004' '01' ... 'áirithe' 'éireann' 'ó']
# INFO:root:Frequencies: [ 29   1 407 ...   1  53   6]
# INFO:root:Terms: ['000' '03' '032' ... 'éireann' 'ó' 'óga']
# INFO:root:Frequencies: [112 358   1 ...  68   9   1]
# INFO:root:Terms: ['00' '000' '02' ... 'ón' 'útóipe' 'šefčovič']
# INFO:root:Frequencies: [  3  84 517 ...   1   1   4]
# INFO:root:Terms: ['000' '014' '02' ... 'ó' 'ónóir' 'údarás']
# INFO:root:Frequencies: [25  1  1 ... 17  1  1]
# INFO:root:Terms: ['0' '000' '04' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [ 11  99 403 ...   5   1   1]
# INFO:root:Terms: ['000' '03' '057' ... 'í' 'ó' 'óglaigh']
# INFO:root:Frequencies: [ 80 620   1 ...   1  48   3]
# INFO:root:Terms: ['0' '000' '0019' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 5 45  1 ...  1 69 18]
# INFO:root:Terms: ['000' '05' '09' ... 'éireann' 'ó' 'óntachtaí']
# INFO:root:Frequencies: [ 57   1 635 ...  88  21   1]
# INFO:root:Terms: ['0' '000' '00100deputy' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [ 1 60  1 ... 22  1  1]
# INFO:root:Terms: ['0' '000' '00100prohibition' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [ 4 62  1 ... 80 25  1]
# INFO:root:Terms: ['0' '000' '027' ... 'ón' 'údarás' 'úis']
# INFO:root:Frequencies: [ 4 49  1 ...  2  2  2]
# INFO:root:Terms: ['0' '000' '000-strong' ... 'éireann-garda' 'íosa' 'ó']
# INFO:root:Frequencies: [ 1 66  1 ...  1  1 18]
# INFO:root:Terms: ['000' '01' '022' ... 'óráid' 'ós' 'úsáid']
# INFO:root:Frequencies: [31  1  1 ...  3  2  1]
# INFO:root:Terms: ['0' '000' '05' ... 'ó' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  1  48 305 ...  69   1   1]
# INFO:root:Terms: ['0' '000' '0009' ... 'éirinn' 'í' 'ó']
# INFO:root:Frequencies: [ 3 85  1 ...  3  1 22]
# INFO:root:Terms: ['0' '000' '024' ... 'ó' 'úinéireacht' 'úsáid']
# INFO:root:Frequencies: [  4 117   1 ...  27   4   2]
# INFO:root:Terms: ['0' '000' '07' ... 'óg' 'óga' 'údarás']
# INFO:root:Frequencies: [  6 105 494 ...   1   1   1]
# INFO:root:Terms: ['000' '000-plus' '04' ... 'í' 'ó' 'óg']
# INFO:root:Frequencies: [83  1  1 ...  1 14  1]
# INFO:root:Terms: ['0' '000' '03' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [  4  60 358 ...  10   2   2]
# INFO:root:Terms: ['0' '000' '03' ... 'ó' 'úra' 'úsáid']
# INFO:root:Frequencies: [  1  62 571 ...  70   1   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [  1  30 392 ...   1  52  16]
# INFO:root:Terms: ['0' '000' '014' ... 'éireannach' 'ó' 'ón']
# INFO:root:Frequencies: [ 2 95  1 ...  1 42  1]
# INFO:root:Terms: ['0' '000' '08' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [  2  56 267 ...   1  67  24]
# INFO:root:Terms: ['0' '00' '000' ... 'ó' 'óga' 'ón']
# INFO:root:Frequencies: [ 6  1 75 ... 67  1  1]
# INFO:root:Terms: ['000' '00100naval' '019' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [30  1  1 ...  2 62 75]
# INFO:root:Terms: ['000' '04' '046' ... 'órlaithí' 'údarás' 'šefčovič']
# INFO:root:Frequencies: [60  1  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [  6  44 422 ...  83  76   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [  2  86 443 ...  70   8   3]
# INFO:root:Terms: ['0' '000' '012' ... 'é' 'éireann' 'ó']
# INFO:root:Frequencies: [ 3 93  1 ...  1 67 57]
# INFO:root:Terms: ['0' '00' '000' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 1  1 43 ... 70 32  2]
# INFO:root:Terms: ['0' '00' '000' ... 'í' 'ó' 'údarás']
# INFO:root:Frequencies: [ 13   1 192 ...   1  20   1]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 6 60  1 ...  2 87 28]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ó' 'ón' 'úsáid']
# INFO:root:Frequencies: [ 5 95  1 ... 86  3  1]
# INFO:root:Terms: ['0' '000' '039' ... 'óga' 'šefcovic' 'šefčovič']
# INFO:root:Frequencies: [ 2 76  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '068' ... 'ós' 'údarás' 'úr']
# INFO:root:Frequencies: [ 16 146   1 ...   1   4   1]
# INFO:root:Terms: ['0' '000' '002' ... 'íoc' 'ó' 'údarás']
# INFO:root:Frequencies: [  9 149   1 ...   1  17   1]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [  2 144   1 ...  32   2   1]
# INFO:root:Terms: ['000' '02' '045' ... 'ó' 'óna' 'úsáid']
# INFO:root:Frequencies: [ 73 528   1 ...  21   1   2]
# INFO:root:Terms: ['0' '000' '080' ... 'óna' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [  3 112   1 ...   2   1   5]
# INFO:root:Terms: ['0' '000' '000-odd' ... 'í' 'ó' 'úinéireacht']
# INFO:root:Frequencies: [ 2 94  1 ...  1 17  2]
# INFO:root:Terms: ['0' '000' '06' ... 'ó' 'óráidí' 'šefčovič']
# INFO:root:Frequencies: [  3  45 494 ...  38   1   4]
# INFO:root:Terms: ['0' '000' '018' ... 'éireann' 'í' 'ó']
# INFO:root:Frequencies: [ 3 60  1 ... 80  4 41]
# INFO:root:Terms: ['0' '000' '02' ... 'éis' 'être' 'ó']
# INFO:root:Frequencies: [  1 127 549 ...   1   2  31]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ómóis' 'ómós' 'šefik']
# INFO:root:Frequencies: [ 4 71  1 ...  1  2  1]
# INFO:root:Terms: ['0' '00' '000' ... 'ó' 'óglaigh' 'ón']
# INFO:root:Frequencies: [ 2  1 45 ... 28  1  3]
# INFO:root:Terms: ['0' '000' '000-pupil' ... 'íosagáin' 'ó' 'údarás']
# INFO:root:Frequencies: [  3 117   1 ...   4  59   2]
# INFO:root:Terms: ['0' '00' '000' ... 'áirithe' 'éireann' 'ó']
# INFO:root:Frequencies: [18  1 48 ...  1 71 16]
# INFO:root:Terms: ['0' '000' '02' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [  1  50 477 ...  51  47   1]
# INFO:root:Terms: ['000' '027' '05' ... 'ó' 'ón' 'úinéireacht']
# INFO:root:Frequencies: [ 40   1 593 ...  11   1   1]
# INFO:root:Terms: ['0' '000' '000-odd' ... 'ós' 'údarás' 'úsáid']
# INFO:root:Frequencies: [ 3 54  1 ...  1  1  3]
# INFO:root:Terms: ['0' '000' '0000' ... 'ó' 'ón' 'úsáideann']
# INFO:root:Frequencies: [ 12 190   1 ...  70   2   1]
# INFO:root:Terms: ['0' '000' '01' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 8 61  1 ... 75 17  2]
# INFO:root:Terms: ['0' '000' '02' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [  8 148   1 ...  90  32   1]
# INFO:root:Terms: ['0' '000' '0042' ... 'zone' 'éireann' 'ó']
# INFO:root:Frequencies: [  1 107   1 ...   2  66   2]
# INFO:root:Terms: ['000' '02' '027' ... 'éireann' 'ó' 'óga']
# INFO:root:Frequencies: [ 60 561   1 ...  66  54   1]
# INFO:root:Terms: ['000' '02' '05' ... 'údaráis' 'údarás' 'úsáid']
# INFO:root:Frequencies: [ 37 520 539 ...   2   4   1]
# INFO:root:Terms: ['0' '000' '02' ... 'úsáid' 'úsáidfidh' 'úsáidtear']
# INFO:root:Frequencies: [  1  48 417 ...   1   1   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éis' 'í' 'ó']
# INFO:root:Frequencies: [ 5 41  1 ...  1  1 49]
# INFO:root:Terms: ['0' '000' '077' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  3 140   2 ...   8  92  28]
# INFO:root:Terms: ['0' '000' '048' ... 'être' 'ó' 'šefovi']
# INFO:root:Frequencies: [ 5 55  1 ...  1 69  1]
# INFO:root:Terms: ['000' '03' '09' ... 'í' 'ó' 'óige']
# INFO:root:Frequencies: [137   1 612 ...   1  35   1]
# INFO:root:Terms: ['0' '000' '02' ... 'óga' 'ós' 'údarás']
# INFO:root:Frequencies: [  3  76 604 ...   1   2   2]
# INFO:root:Terms: ['000' '012' '02' ... 'úinéireacht' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 81   1 501 ...   1   2   1]
# INFO:root:Terms: ['0' '000' '006' ... 'údarás' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 3 50  1 ...  9  1  2]
# INFO:root:Terms: ['0' '000' '03' ... 'éire' 'éireann' 'ó']
# INFO:root:Frequencies: [  1  26 457 ...   1  85  13]
# INFO:root:Terms: ['000' '001' '01' ... 'ó' 'óir' 'šefčovič']
# INFO:root:Frequencies: [138   1   1 ...  70   1   1]
# INFO:root:Terms: ['000' '010' '012' ... 'ón' 'údarás' 'úrlar']
# INFO:root:Frequencies: [77  2  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '000-units-per' ... 'ón' 'ór' 'úachtaráin']
# INFO:root:Frequencies: [  3 145   1 ...   2   1   1]
# INFO:root:Terms: ['0' '000' '099' ... 'éireann' 'éis' 'ó']
# INFO:root:Frequencies: [ 6 89  1 ... 71  1 36]
# INFO:root:Terms: ['0' '0-17' '000' ... 'é' 'éireann' 'ó']
# INFO:root:Frequencies: [ 7  1 96 ...  1 91  9]
# INFO:root:Terms: ['0' '000' '003' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [ 2 58  1 ... 13  3  7]
# INFO:root:Terms: ['0' '000' '01' ... 'óg' 'ón' 'úsáid']
# INFO:root:Frequencies: [  5  98 794 ...   1   1   2]
# INFO:root:Terms: ['0' '000' '0000' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [  4 178   1 ...  26   2   1]
# INFO:root:Terms: ['0' '000' '030' ... 'íoc' 'ó' 'ón']
# INFO:root:Frequencies: [ 1 53  1 ...  1 18  1]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'éisteacht' 'íosagáin' 'ó']
# INFO:root:Frequencies: [ 9 89  1 ...  1  2  6]
# INFO:root:Terms: ['0' '000' '007' ... 'í' 'ó' 'ón']
# INFO:root:Frequencies: [ 1 75  1 ...  1 53  1]
# INFO:root:Terms: ['0' '000' '02' ... 'ón' 'úr' 'úsáid']
# INFO:root:Frequencies: [  9 144   1 ...   1   1   1]
# INFO:root:Terms: ['0' '000' '006' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  4 146   1 ...  30  83  79]
# INFO:root:Terms: ['0' '000' '000-litre' ... 'íoc' 'íre' 'ó']
# INFO:root:Frequencies: [ 2 68  2 ...  1  1 13]
# INFO:root:Terms: ['0' '000' '03' ... 'ón' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  6  51 629 ...   4   2   2]
# INFO:root:Terms: ['000' '02' '09' ... 'éisteacht' 'ó' 'óna']
# INFO:root:Frequencies: [ 61   1 488 ...   1  10   1]
# INFO:root:Terms: ['0' '00' '000' ... 'óga' 'ón' 'úcráin']
# INFO:root:Frequencies: [ 12   1 210 ...   1   1   1]
# INFO:root:Terms: ['0' '000' '001' ... 'ó' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 3 49  1 ... 45  2  1]
# INFO:root:Terms: ['0' '000' '0000' ... 'ó' 'ón' 'úsáid']
# INFO:root:Frequencies: [  2 152   1 ...  75   1   1]
# INFO:root:Terms: ['0' '00' '000' ... 'être' 'ísle' 'ó']
# INFO:root:Frequencies: [  2   1 109 ...   1   1  32]
# INFO:root:Terms: ['0' '000' '02' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  1  83 384 ...   2  55   4]
# INFO:root:Terms: ['0' '000' '007' ... 'éireann' 'íocaíocht' 'ó']
# INFO:root:Frequencies: [ 1 72  1 ... 56  1  6]
# INFO:root:Terms: ['0' '000' '000th' ... 'ón' 'ótuathail' 'úchtarán']
# INFO:root:Frequencies: [ 2 51  1 ...  2  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'éireann' 'ó' 'úsaide']
# INFO:root:Frequencies: [  9  93 478 ...  72  18   1]
# INFO:root:Terms: ['0' '00' '000' ... 'éis' 'í' 'ó']
# INFO:root:Frequencies: [  2   3 173 ...   1   1  36]
# INFO:root:Terms: ['0' '000' '003' ... 'ón' 'óna' 'úsáid']
# INFO:root:Frequencies: [ 1 76  1 ...  1  1  1]
# INFO:root:Terms: ['0' '000' '03' ... 'ón' 'ós' 'úis']
# INFO:root:Frequencies: [  8  57 560 ...   4   1   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  1  38 445 ...   2  55   6]
# INFO:root:Terms: ['0' '00' '000' ... 'í' 'íarnród' 'ó']
# INFO:root:Frequencies: [  6   1 114 ...   1   1  39]
# INFO:root:Terms: ['0' '00' '000' ... 'ó' 'óglaigh' 'ón']
# INFO:root:Frequencies: [ 7  1 60 ...  6  6  1]
# INFO:root:Terms: ['000' '04' '05' ... 'zurich' 'éireann' 'ó']
# INFO:root:Frequencies: [ 23 201   2 ...   1  43  15]
# INFO:root:Terms: ['0' '000' '04' ... 'ó' 'óga' 'šefčovič']
# INFO:root:Frequencies: [  2 216 478 ...  38   2   3]
# INFO:root:Terms: ['0' '000' '00100deputy' ... 'údarás' 'úir' 'úsáid']
# INFO:root:Frequencies: [  4 106   1 ...   6   1   4]
# INFO:root:Terms: ['000' '009' '05' ... 'é' 'éireann' 'ó']
# INFO:root:Frequencies: [ 41   1 497 ...   1  76  10]
# INFO:root:Terms: ['0' '00' '000' ... 'údarás' 'úsáid' 'úsáideann']
# INFO:root:Frequencies: [ 8  1 34 ... 10  2  2]
# INFO:root:Terms: ['0' '000' '015' ... 'ó' 'ørsted' 'úna']
# INFO:root:Frequencies: [  4 101   1 ...  21   1   1]
# INFO:root:Terms: ['0' '000' '000-tonne' ... 'úr' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 1 39  3 ...  1  1  2]
# INFO:root:Terms: ['0' '000' '028' ... 'íseal' 'ó' 'óna']
# INFO:root:Frequencies: [ 3 51  1 ...  1 33  1]
# INFO:root:Terms: ['0' '00' '000' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [  4   1 126 ...   1  64  19]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ó' 'óga' 'údarás']
# INFO:root:Frequencies: [  3 120   1 ...  28   1   1]
# INFO:root:Terms: ['0' '000' '017' ... 'ó' 'óige' 'údarás']
# INFO:root:Frequencies: [ 17 137   1 ...  12   1   4]
# INFO:root:Terms: ['0' '0-18' '000' ... 'ó' 'óga' 'ón']
# INFO:root:Frequencies: [ 4  1 74 ... 26  1  1]
# INFO:root:Terms: ['0' '000' '001' ... 'ó' 'óg' 'ón']
# INFO:root:Frequencies: [ 5 87  1 ... 22  3  2]
# INFO:root:Terms: ['0' '000' '05' ... 'ón' 'óráidí' 'úsáide']
# INFO:root:Frequencies: [ 1 69  2 ...  3  1  1]
# INFO:root:Terms: ['0' '000' '04' ... 'íocfaidh' 'ó' 'óglaigh']
# INFO:root:Frequencies: [ 15 181   1 ...   2  19   1]
# INFO:root:Terms: ['0' '000' '0000' ... 'ón' 'ós' 'šefčovič']
# INFO:root:Frequencies: [  2 102   1 ...   1   1   1]
# INFO:root:Terms: ['000' '01' '03' ... 'ó' 'ócáid' 'ón']
# INFO:root:Frequencies: [ 57 533 551 ...  33   2   2]
# INFO:root:Terms: ['0' '000' '000-pupil' ... 'í' 'ó' 'ón']
# INFO:root:Frequencies: [ 6 89  1 ...  2 32  1]
# INFO:root:Terms: ['0' '000' '04' ... 'ó' 'ón' 'úinéirí']
# INFO:root:Frequencies: [  1 154 590 ...  55   4   2]
# INFO:root:Terms: ['0' '000' '03' ... 'éireann' 'éist' 'ó']
# INFO:root:Frequencies: [  3  73   1 ... 102   1  39]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ón' 'úis' 'ús']
# INFO:root:Frequencies: [25 70  1 ...  2  5  1]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ó' 'óga' 'ón']
# INFO:root:Frequencies: [  3 103   1 ...  31   3   1]
# INFO:root:Terms: ['0' '000' '05' ... 'éireann' 'ó' 'óg']
# INFO:root:Frequencies: [  3  55 561 ... 129  16   1]
# INFO:root:Terms: ['0' '00' '000' ... 'ón' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  9   1 110 ...   2   1   6]
# INFO:root:Terms: ['0' '000' '03' ... 'údar' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 8 59  1 ...  2  4  7]
# INFO:root:Terms: ['0' '000' '01' ... 'óga' 'óglaigh' 'údarás']
# INFO:root:Frequencies: [ 12 189   1 ...   1   1   3]
# INFO:root:Terms: ['000' '048' '07' ... 'éis' 'ó' 'ón']
# INFO:root:Frequencies: [134   1   1 ...   1  56   4]
# INFO:root:Terms: ['0' '000' '000dáil' ... 'éireann' 'ó' 'údarás']
# INFO:root:Frequencies: [14 98  1 ... 95 14  1]
# INFO:root:Terms: ['0' '000' '057' ... 'éamon' 'éireann' 'ó']
# INFO:root:Frequencies: [ 1 74  1 ...  5 93 29]
# INFO:root:Terms: ['0' '000' '028' ... 'éireann' 'ó' 'ón']
# INFO:root:Frequencies: [ 6 92  1 ... 89 47  1]
# INFO:root:Terms: ['0' '000' '028' ... 'ón' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  4 177   1 ...   1  10   2]
# INFO:root:Terms: ['0' '000' '03' ... 'óráid' 'údarás' 'úsáid']
# INFO:root:Frequencies: [  9 155   1 ...   1   5   1]
# INFO:root:Terms: ['0' '000' '034' ... 'údarás' 'úsáid' 'úsáideann']
# INFO:root:Frequencies: [  2 119   1 ...   2   3   1]
# INFO:root:Terms: ['0' '00' '000' ... 'í' 'ó' 'údarás']
# INFO:root:Frequencies: [16  1 59 ...  1 98  3]
# INFO:root:Terms: ['0' '00' '000' ... 'ó' 'ón' 'údarás']
# INFO:root:Frequencies: [ 10   1 170 ...   5   1   3]
# INFO:root:Terms: ['000' '003' '01' ... 'éireann' 'íosagáin' 'ó']
# INFO:root:Frequencies: [88  1  1 ... 77  1 23]
# INFO:root:Terms: ['0' '000' '01' ... 'ó' 'údarás' 'úr']
# INFO:root:Frequencies: [  4  56 583 ...  32   1   1]
# INFO:root:Terms: ['0' '000' '049' ... 'éis' 'íseal' 'ó']
# INFO:root:Frequencies: [ 1 48  1 ...  1  1 27]
# INFO:root:Terms: ['0' '000' '000-plus' ... 'ó' 'ón' 'šefčovič']
# INFO:root:Frequencies: [  7 106   1 ... 109   2   1]
# INFO:root:Terms: ['0' '000' '03' ... 'éireann' 'í' 'ó']
# INFO:root:Frequencies: [  6  63 512 ...  84   1   7]
# INFO:root:Terms: ['0' '000' '000-strong' ... 'údaráis' 'údarás' 'šefčovič']
# INFO:root:Frequencies: [  7 174   1 ...   1   6   1]
# INFO:root:Terms: ['0' '000' '0002' ... 'údarás' 'úsáid' 'šefčovič']
# INFO:root:Frequencies: [ 8 96  1 ...  1  1  4]
# INFO:root:Terms: ['0' '000' '009' ... 'óige' 'ón' 'údarás']
# INFO:root:Frequencies: [ 3 90  1 ...  1  1  3]
# INFO:root:Terms: ['0' '000' '044' ... 'éisteacht' 'ó' 'óga']
# INFO:root:Frequencies: [ 15 155   1 ...   1  16   1]
# ...
# INFO:root:670521f275d9daeff229ce81
# INFO:root:670521f275d9daeff229ce82
# INFO:root:670521f275d9daeff229ce83
# INFO:root:670521f275d9daeff229ce84
# INFO:root:670521f275d9daeff229ce85
# INFO:root:670521f275d9daeff229ce86
# INFO:root:670521f275d9daeff229ce87
# INFO:root:670521f275d9daeff229ce88
# INFO:root:670521f275d9daeff229ce89
# INFO:root:670521f275d9daeff229ce8a
# INFO:root:670521f275d9daeff229ce8b
# INFO:root:670521f275d9daeff229ce8c
# INFO:root:670521f275d9daeff229ce8d
# INFO:root:670521f275d9daeff229ce8e
# INFO:root:670521f275d9daeff229ce8f
# INFO:root:670521f275d9daeff229ce90
# INFO:root:670521f275d9daeff229ce91
# INFO:root:670521f275d9daeff229ce92
# INFO:root:670521f275d9daeff229ce93
# INFO:root:670521f275d9daeff229ce94
# INFO:root:670521f275d9daeff229ce95
# INFO:root:670521f275d9daeff229ce96
# INFO:root:670521f275d9daeff229ce97
# INFO:root:670521f275d9daeff229ce98
# INFO:root:670521f275d9daeff229ce99
# INFO:root:670521f275d9daeff229ce9a
# INFO:root:670521f275d9daeff229ce9b
# INFO:root:670521f275d9daeff229ce9c
# INFO:root:670521f275d9daeff229ce9d
# INFO:root:670521f275d9daeff229ce9e
# INFO:root:670521f275d9daeff229ce9f
# INFO:root:670521f275d9daeff229cea0
# INFO:root:670521f275d9daeff229cea1
# INFO:root:670521f275d9daeff229cea2
# INFO:root:670521f275d9daeff229cea3
# INFO:root:670521f275d9daeff229cea4
# INFO:root:670521f275d9daeff229cea5
# INFO:root:670521f275d9daeff229cea6
# INFO:root:670521f275d9daeff229cea7
# INFO:root:670521f275d9daeff229cea8
# INFO:root:670521f275d9daeff229cea9
# INFO:root:670521f275d9daeff229ceaa
# INFO:root:670521f275d9daeff229ceab
# INFO:root:670521f275d9daeff229ceac
# INFO:root:670521f275d9daeff229cead
# INFO:root:670521f275d9daeff229ceae
# INFO:root:670521f275d9daeff229ceaf
# INFO:root:670521f275d9daeff229ceb0
# INFO:root:670521f275d9daeff229ceb1
# INFO:root:670521f275d9daeff229ceb2
# INFO:root:670521f275d9daeff229ceb3
# INFO:root:670521f275d9daeff229ceb4
# INFO:root:670521f275d9daeff229ceb5
# INFO:root:670521f275d9daeff229ceb6
# INFO:root:670521f275d9daeff229ceb7
# INFO:root:670521f275d9daeff229ceb8
# INFO:root:670521f275d9daeff229ceb9
# INFO:root:670521f275d9daeff229ceba
# INFO:root:670521f275d9daeff229cebb
# INFO:root:670521f275d9daeff229cebc
# INFO:root:670521f275d9daeff229cebd
# INFO:root:670521f275d9daeff229cebe
# INFO:root:670521f275d9daeff229cebf
# INFO:root:670521f275d9daeff229cec0
# INFO:root:670521f275d9daeff229cec1
# INFO:root:670521f275d9daeff229cec2
# INFO:root:670521f275d9daeff229cec3
# INFO:root:670521f275d9daeff229cec4
# INFO:root:670521f275d9daeff229cec5
# INFO:root:670521f275d9daeff229cec6
# INFO:root:670521f275d9daeff229cec7
# INFO:root:670521f275d9daeff229cec8
# INFO:root:670521f275d9daeff229cec9
# INFO:root:670521f275d9daeff229ceca
# INFO:root:670521f275d9daeff229cecb
# INFO:root:670521f275d9daeff229cecc
# INFO:root:670521f275d9daeff229cecd
# INFO:root:670521f275d9daeff229cece
# INFO:root:670521f275d9daeff229cecf
# INFO:root:670521f275d9daeff229ced0
# INFO:root:670521f275d9daeff229ced1
# INFO:root:670521f275d9daeff229ced2
# INFO:root:670521f275d9daeff229ced3
# INFO:root:670521f275d9daeff229ced4
# INFO:root:670521f275d9daeff229ced5
# INFO:root:670521f275d9daeff229ced6
# INFO:root:670521f275d9daeff229ced7
# INFO:root:670521f275d9daeff229ced8
# INFO:root:670521f275d9daeff229ced9
# INFO:root:670521f275d9daeff229ceda
# INFO:root:670521f275d9daeff229cedb
# INFO:root:670521f275d9daeff229cedc
# INFO:root:670521f275d9daeff229cedd
# INFO:root:670521f275d9daeff229cede
# INFO:root:670521f275d9daeff229cedf
# INFO:root:670521f275d9daeff229cee0
# INFO:root:670521f275d9daeff229cee1
# INFO:root:670521f275d9daeff229cee2
# INFO:root:670521f275d9daeff229cee3
# INFO:root:670521f275d9daeff229cee4
# INFO:root:670521f275d9daeff229cee5
# INFO:root:670521f275d9daeff229cee6
# INFO:root:670521f275d9daeff229cee7
# INFO:root:670521f275d9daeff229cee8
# INFO:root:670521f275d9daeff229cee9
# INFO:root:670521f275d9daeff229ceea
# INFO:root:670521f275d9daeff229ceeb
# INFO:root:670521f275d9daeff229ceec
# INFO:root:670521f275d9daeff229ceed
# INFO:root:670521f275d9daeff229ceee
# INFO:root:670521f275d9daeff229ceef
# INFO:root:670521f275d9daeff229cef0
# INFO:root:670521f275d9daeff229cef1
# INFO:root:670521f275d9daeff229cef2
# INFO:root:670521f275d9daeff229cef3
# INFO:root:670521f275d9daeff229cef4
# INFO:root:670521f275d9daeff229cef5
# INFO:root:670521f275d9daeff229cef6
# INFO:root:670521f275d9daeff229cef7
# INFO:root:670521f275d9daeff229cef8
# INFO:root:670521f275d9daeff229cef9
# INFO:root:670521f275d9daeff229cefa
# INFO:root:670521f275d9daeff229cefb
# INFO:root:670521f275d9daeff229cefc
# INFO:root:670521f275d9daeff229cefd
# INFO:root:670521f275d9daeff229cefe
# INFO:root:670521f275d9daeff229ceff
# INFO:root:670521f275d9daeff229cf00
# INFO:root:670521f275d9daeff229cf01
# INFO:root:670521f275d9daeff229cf02
# INFO:root:670521f275d9daeff229cf03
# INFO:root:670521f275d9daeff229cf04
# INFO:root:670521f275d9daeff229cf05
# INFO:root:670521f275d9daeff229cf06
# INFO:root:670521f275d9daeff229cf07
# INFO:root:670521f275d9daeff229cf08
# INFO:root:670521f275d9daeff229cf09
# INFO:root:670521f275d9daeff229cf0a
# INFO:root:670521f275d9daeff229cf0b
# INFO:root:670521f275d9daeff229cf0c
# INFO:root:670521f275d9daeff229cf0d
# INFO:root:670521f275d9daeff229cf0e
# INFO:root:670521f275d9daeff229cf0f
# INFO:root:670521f275d9daeff229cf10
# INFO:root:670521f275d9daeff229cf11
# INFO:root:670521f275d9daeff229cf12
# INFO:root:670521f275d9daeff229cf13
# INFO:root:670521f275d9daeff229cf14
# INFO:root:670521f275d9daeff229cf15
# INFO:root:670521f275d9daeff229cf16
# INFO:root:670521f275d9daeff229cf17
# INFO:root:670521f275d9daeff229cf18
# INFO:root:670521f275d9daeff229cf19
# INFO:root:670521f275d9daeff229cf1a
# INFO:root:670521f275d9daeff229cf1b
# INFO:root:670521f275d9daeff229cf1c
# INFO:root:670521f275d9daeff229cf1d
# INFO:root:670521f275d9daeff229cf1e
# INFO:root:670521f275d9daeff229cf1f
# INFO:root:670521f275d9daeff229cf20
# INFO:root:670521f275d9daeff229cf21
# INFO:root:670521f275d9daeff229cf22
# INFO:root:670521f275d9daeff229cf23
# INFO:root:670521f275d9daeff229cf24
# INFO:root:670521f275d9daeff229cf25
# INFO:root:670521f275d9daeff229cf26
# INFO:root:670521f275d9daeff229cf27
# INFO:root:670521f275d9daeff229cf28
# INFO:root:670521f275d9daeff229cf29
# INFO:root:670521f275d9daeff229cf2a
# INFO:root:670521f275d9daeff229cf2b
# INFO:root:670521f275d9daeff229cf2c
# INFO:root:670521f275d9daeff229cf2d
# INFO:root:670521f275d9daeff229cf2e
# INFO:root:670521f275d9daeff229cf2f
# INFO:root:670521f275d9daeff229cf30
# INFO:root:670521f275d9daeff229cf31
# INFO:root:670521f275d9daeff229cf32
# INFO:root:670521f275d9daeff229cf33
# INFO:root:670521f275d9daeff229cf34
# INFO:root:670521f275d9daeff229cf35
# INFO:root:670521f275d9daeff229cf36
# INFO:root:670521f275d9daeff229cf37
# INFO:root:670521f275d9daeff229cf38
# INFO:root:670521f275d9daeff229cf39
# INFO:root:670521f275d9daeff229cf3a
# INFO:root:670521f275d9daeff229cf3b
# INFO:root:670521f275d9daeff229cf3c
# INFO:root:670521f275d9daeff229cf3d
# INFO:root:670521f275d9daeff229cf3e
# INFO:root:670521f275d9daeff229cf3f
# INFO:root:670521f275d9daeff229cf40
# INFO:root:670521f275d9daeff229cf41
# INFO:root:670521f275d9daeff229cf42
# INFO:root:670521f275d9daeff229cf43
# INFO:root:670521f275d9daeff229cf44
# INFO:root:670521f275d9daeff229cf45
# INFO:root:670521f275d9daeff229cf46
# INFO:root:670521f275d9daeff229cf47
# INFO:root:670521f275d9daeff229cf48
# INFO:root:670521f275d9daeff229cf49
# INFO:root:670521f275d9daeff229cf4a
# INFO:root:670521f275d9daeff229cf4b
# INFO:root:670521f275d9daeff229cf4c
# INFO:root:670521f275d9daeff229cf4d
# INFO:root:670521f275d9daeff229cf4e
# INFO:root:670521f275d9daeff229cf4f
# INFO:root:670521f275d9daeff229cf50
# INFO:root:670521f275d9daeff229cf51
# INFO:root:670521f275d9daeff229cf52
# INFO:root:670521f275d9daeff229cf53
# INFO:root:670521f275d9daeff229cf54
# INFO:root:670521f275d9daeff229cf55
# INFO:root:670521f275d9daeff229cf56
# INFO:root:670521f275d9daeff229cf57
# INFO:root:670521f275d9daeff229cf58
# INFO:root:670521f275d9daeff229cf59
# INFO:root:670521f275d9daeff229cf5a
# INFO:root:670521f275d9daeff229cf5b
# INFO:root:670521f275d9daeff229cf5c
# INFO:root:670521f275d9daeff229cf5d
# INFO:root:670521f275d9daeff229cf5e
# INFO:root:670521f275d9daeff229cf5f
# INFO:root:670521f275d9daeff229cf60
# INFO:root:670521f275d9daeff229cf61
# INFO:root:670521f275d9daeff229cf62
# INFO:root:670521f275d9daeff229cf63
# INFO:root:670521f275d9daeff229cf64
# INFO:root:670521f275d9daeff229cf65
# INFO:root:670521f275d9daeff229cf66
# INFO:root:670521f275d9daeff229cf67
# INFO:root:670521f275d9daeff229cf68
# INFO:root:670521f275d9daeff229cf69
# INFO:root:670521f275d9daeff229cf6a
# INFO:root:670521f275d9daeff229cf6b
# INFO:root:670521f275d9daeff229cf6c
# INFO:root:670521f275d9daeff229cf6d
# INFO:root:670521f275d9daeff229cf6e
# INFO:root:670521f275d9daeff229cf6f
# INFO:root:670521f275d9daeff229cf70
# INFO:root:670521f275d9daeff229cf71
# INFO:root:670521f275d9daeff229cf72
# INFO:root:670521f275d9daeff229cf73
# INFO:root:670521f275d9daeff229cf74
# INFO:root:670521f275d9daeff229cf75
# INFO:root:670521f275d9daeff229cf76
# INFO:root:670521f275d9daeff229cf77
# INFO:root:670521f275d9daeff229cf78
# INFO:root:670521f275d9daeff229cf79
# INFO:root:670521f275d9daeff229cf7a
# INFO:root:670521f275d9daeff229cf7b
# INFO:root:670521f275d9daeff229cf7c
# INFO:root:670521f275d9daeff229cf7d
# INFO:root:670521f275d9daeff229cf7e
# INFO:root:670521f275d9daeff229cf7f
# INFO:root:670521f275d9daeff229cf80
# INFO:root:670521f275d9daeff229cf81
# INFO:root:670521f275d9daeff229cf82
# INFO:root:670521f275d9daeff229cf83
# INFO:root:670521f275d9daeff229cf84
# INFO:root:670521f275d9daeff229cf85
# INFO:root:670521f275d9daeff229cf86
# INFO:root:670521f275d9daeff229cf87
# INFO:root:670521f275d9daeff229cf88
# INFO:root:670521f275d9daeff229cf89
# INFO:root:670521f275d9daeff229cf8a
# INFO:root:670521f275d9daeff229cf8b
# INFO:root:670521f275d9daeff229cf8c
# INFO:root:670521f275d9daeff229cf8d
# INFO:root:670521f275d9daeff229cf8e
# INFO:root:670521f275d9daeff229cf8f
# INFO:root:670521f275d9daeff229cf90
# INFO:root:670521f275d9daeff229cf91
# INFO:root:670521f275d9daeff229cf92
# INFO:root:670521f275d9daeff229cf93
# INFO:root:670521f275d9daeff229cf94
# INFO:root:670521f275d9daeff229cf95
# INFO:root:670521f275d9daeff229cf96
# INFO:root:670521f275d9daeff229cf97
# INFO:root:670521f275d9daeff229cf98
# INFO:root:670521f275d9daeff229cf99
# INFO:root:670521f275d9daeff229cf9a
# INFO:root:670521f275d9daeff229cf9b
# INFO:root:670521f275d9daeff229cf9c
# INFO:root:670521f275d9daeff229cf9d
# INFO:root:670521f275d9daeff229cf9e
# INFO:root:670521f275d9daeff229cf9f
# INFO:root:670521f275d9daeff229cfa0
# INFO:root:670521f275d9daeff229cfa1
# INFO:root:670521f275d9daeff229cfa2
# INFO:root:670521f275d9daeff229cfa3
# INFO:root:670521f275d9daeff229cfa4
# INFO:root:670521f275d9daeff229cfa5
# INFO:root:670521f275d9daeff229cfa6
# INFO:root:670521f275d9daeff229cfa7
# INFO:root:670521f275d9daeff229cfa8
# INFO:root:670521f275d9daeff229cfa9
# INFO:root:670521f275d9daeff229cfaa
# INFO:root:670521f275d9daeff229cfab
# INFO:root:670521f275d9daeff229cfac
# INFO:root:670521f275d9daeff229cfad
# INFO:root:670521f275d9daeff229cfae
# INFO:root:670521f275d9daeff229cfaf
# INFO:root:670521f275d9daeff229cfb0
# INFO:root:670521f275d9daeff229cfb1
# INFO:root:670521f275d9daeff229cfb2
# INFO:root:670521f275d9daeff229cfb3
# INFO:root:670521f275d9daeff229cfb4
# INFO:root:670521f275d9daeff229cfb5
# INFO:root:670521f275d9daeff229cfb6
# INFO:root:670521f275d9daeff229cfb7
# INFO:root:670521f275d9daeff229cfb8
# INFO:root:670521f275d9daeff229cfb9
# INFO:root:670521f275d9daeff229cfba
# INFO:root:670521f275d9daeff229cfbb
# INFO:root:670521f275d9daeff229cfbc
# INFO:root:670521f275d9daeff229cfbd
# INFO:root:670521f275d9daeff229cfbe
# INFO:root:670521f275d9daeff229cfbf
# INFO:root:670521f275d9daeff229cfc0
# INFO:root:670521f275d9daeff229cfc1
# INFO:root:670521f275d9daeff229cfc2
# INFO:root:670521f275d9daeff229cfc3
# INFO:root:670521f275d9daeff229cfc4
# INFO:root:670521f275d9daeff229cfc5
# INFO:root:670521f275d9daeff229cfc6
# INFO:root:670521f275d9daeff229cfc7
# INFO:root:670521f275d9daeff229cfca
# INFO:root:670521f275d9daeff229cfcb
# INFO:root:670521f275d9daeff229cfcc
# INFO:root:670521f275d9daeff229cfcd
# INFO:root:670521f275d9daeff229cfcf
# INFO:root:670521f275d9daeff229cfd0
# INFO:root:670521f275d9daeff229cfd1
# INFO:root:670521f275d9daeff229cfd8
# INFO:root:670521f275d9daeff229cfd9
# INFO:root:670521f275d9daeff229cfda
# INFO:root:670521f275d9daeff229cfdb
# INFO:root:670521f275d9daeff229cfdc
# INFO:root:670521f275d9daeff229cfdd
# INFO:root:670521f275d9daeff229cfde
# INFO:root:670521f275d9daeff229cfdf
# INFO:root:670521f275d9daeff229cfe0
# INFO:root:670521f275d9daeff229cfe1
# INFO:root:670521f275d9daeff229cfe2
# INFO:root:670521f275d9daeff229cfe3
# INFO:root:670521f275d9daeff229cfe4
# INFO:root:670521f275d9daeff229cfe5
# INFO:root:670521f275d9daeff229cfe6
# INFO:root:670521f275d9daeff229cfe7
# INFO:root:670521f275d9daeff229cfe8
# INFO:root:670521f275d9daeff229cfe9
# INFO:root:670521f275d9daeff229cfea
# INFO:root:670521f275d9daeff229cfeb
# INFO:root:670521f275d9daeff229cfec
# INFO:root:670521f275d9daeff229cfed
# INFO:root:670521f275d9daeff229cfee
# INFO:root:670521f275d9daeff229cfef
# INFO:root:670521f275d9daeff229cff0
# INFO:root:670521f275d9daeff229cff1
# INFO:root:670521f275d9daeff229cff2
# INFO:root:670521f275d9daeff229cff3
# INFO:root:670521f275d9daeff229cff4
# INFO:root:670521f275d9daeff229cff5
# INFO:root:670521f275d9daeff229cff6
# INFO:root:670521f275d9daeff229cff7
# INFO:root:670521f275d9daeff229cff8
# INFO:root:670521f275d9daeff229cff9
# INFO:root:670521f275d9daeff229cffa
# INFO:root:670521f275d9daeff229cffb
# INFO:root:670521f275d9daeff229cffc
# INFO:root:670521f275d9daeff229cffd
# INFO:root:670521f275d9daeff229cffe
# INFO:root:670521f275d9daeff229cfff
# INFO:root:670521f275d9daeff229d000
# INFO:root:670521f275d9daeff229d001
# INFO:root:670521f275d9daeff229d002
# INFO:root:670521f275d9daeff229d003
# INFO:root:670521f275d9daeff229d004
# INFO:root:670521f275d9daeff229d005
# INFO:root:670521f275d9daeff229d006
# INFO:root:670521f275d9daeff229d007
# INFO:root:670521f275d9daeff229d008
# INFO:root:670521f275d9daeff229d009
# INFO:root:670521f275d9daeff229d00a
# INFO:root:670521f275d9daeff229d00b
# INFO:root:670521f275d9daeff229d00c
# INFO:root:670521f275d9daeff229d00d
# INFO:root:670521f275d9daeff229d00e
# INFO:root:670521f275d9daeff229d00f
# INFO:root:670521f275d9daeff229d010
# INFO:root:670521f275d9daeff229d011
# INFO:root:670521f275d9daeff229d012
# INFO:root:670521f275d9daeff229d013
# INFO:root:670521f275d9daeff229d014
# INFO:root:670521f275d9daeff229d015
# INFO:root:670521f275d9daeff229d016
# INFO:root:670521f275d9daeff229d017
# INFO:root:670521f275d9daeff229d018
# INFO:root:670521f275d9daeff229d019
# INFO:root:670521f275d9daeff229d01a
# INFO:root:670521f275d9daeff229d01b
# INFO:root:670521f275d9daeff229d01c
# INFO:root:670521f275d9daeff229d01d
# INFO:root:670521f275d9daeff229d01e
# INFO:root:670521f275d9daeff229d01f
# INFO:root:670521f275d9daeff229d020
# INFO:root:670521f275d9daeff229d021
# INFO:root:670521f275d9daeff229d022
# INFO:root:670521f275d9daeff229d023
# INFO:root:670521f275d9daeff229d024
# INFO:root:670521f275d9daeff229d025
# INFO:root:670521f275d9daeff229d026
# INFO:root:670521f275d9daeff229d027
# INFO:root:670521f275d9daeff229d028
# INFO:root:670521f275d9daeff229d029
# INFO:root:670521f275d9daeff229d02a
# INFO:root:670521f275d9daeff229d02b
# INFO:root:670521f275d9daeff229d02c
# INFO:root:670521f275d9daeff229d02d
# INFO:root:670521f275d9daeff229d02e
# INFO:root:670521f275d9daeff229d02f
# INFO:root:670521f275d9daeff229d030
# INFO:root:670521f275d9daeff229d031
# INFO:root:670521f275d9daeff229d032
# INFO:root:670521f275d9daeff229d033
# INFO:root:670521f275d9daeff229d034
# INFO:root:670521f275d9daeff229d035
# INFO:root:670521f275d9daeff229d036
# INFO:root:670521f275d9daeff229d037
# INFO:root:670521f275d9daeff229d038
# INFO:root:670521f275d9daeff229d039
# INFO:root:670521f275d9daeff229d03a
# INFO:root:670521f275d9daeff229d03b
# INFO:root:670521f275d9daeff229d03c
# INFO:root:670521f275d9daeff229d03d
# INFO:root:670521f275d9daeff229d03e
# INFO:root:670521f275d9daeff229d03f
# INFO:root:670521f275d9daeff229d040
# INFO:root:670521f275d9daeff229d041
# INFO:root:670521f275d9daeff229d042
# INFO:root:670521f275d9daeff229d043
# INFO:root:670521f275d9daeff229d044
# INFO:root:670521f275d9daeff229d045
# INFO:root:670521f275d9daeff229d046
# INFO:root:670521f275d9daeff229d047
# INFO:root:670521f275d9daeff229d048
# INFO:root:670521f275d9daeff229d049
# INFO:root:670521f275d9daeff229d04a
# INFO:root:670521f275d9daeff229d04b
# INFO:root:670521f275d9daeff229d04c
# INFO:root:670521f275d9daeff229d04d
# INFO:root:670521f275d9daeff229d04e
# INFO:root:670521f275d9daeff229d04f
# INFO:root:670521f275d9daeff229d050
# INFO:root:670521f275d9daeff229d051
# INFO:root:670521f275d9daeff229d052

# %%
def clean_term(term):
    # Remove leading and trailing underscores
    return term.strip('_')

# %%
k1 = 'animal_health_levies_'
k2 = '_regulations_2019'
print(clean_term(k1))
print(clean_term(k2))
# Out:
# animal_health_levies
# regulations_2019

# %%
def clean_term_document_matrix(term_document_matrix):
    cleaned_matrix = {}
    for term, frequency in term_document_matrix.items():
        cleaned_term = clean_term(term)
        cleaned_matrix[cleaned_term] = frequency
    return cleaned_matrix

def update_term_document_matrix(collection):
    # Fetch all documents from the collection
    documents = collection.find()
    
    for document in documents:
        if "Term Document Matrix" in document:
            term_document_matrix = document["Term Document Matrix"]
            cleaned_matrix = clean_term_document_matrix(term_document_matrix)
            
            collection.update_one(
                {"_id": document["_id"]},
                {"$set": {"Term Document Matrix": cleaned_matrix}}
            )

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client["transcripts"]
collection = db["complete_documents"]

update_term_document_matrix(collection)
