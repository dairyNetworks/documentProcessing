# %% [markdown]
# # Extracting Speaker and Texts and Topic Modelling
#
# ## The Speaker names and thier corresponding Texts are extracted from the Public Account transcripts, and arranged / categorized by 2 year intervals, followed by Topic Modelling using NMF.

# %% [markdown]
# ### Importing Libraries

# %%
import fitz
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer
import os
from pymongo import MongoClient
from langdetect import detect
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary

# %% [markdown]
# ### Reading Files Names and Years
#
# #### Reading the files from the source folder and joining with the MongoDB Metadata Collection to get the year of publish, and categorising each file in a two-year interval category.

# %%
def extract_year_pdf_files(base_folder, db_url, db_name, collection_name):
    pdf_files = []
    
    # Recursively traverse through all subfolders
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            if file.endswith('.pdf'):
                pdf_files.append(os.path.join(root, file))
    
    pdf_df = pd.DataFrame([os.path.splitext(os.path.basename(f))[0] for f in pdf_files], columns=['file_name'])
    
    # Connect to MongoDB
    client = MongoClient(db_url)
    db = client[db_name]
    collection = db[collection_name]
    
    # Fetch data from MongoDB collection
    mongo_data = list(collection.find({}, {'_id': 0, 'Title': 1, 'Publish_Year': 1, 'ID': 1}))
    mongo_df = pd.DataFrame(mongo_data)
    mongo_df['Year'] = mongo_df['Publish_Year']
    
    # Normalize file names for merging
    pdf_df['file_name'] = pdf_df['file_name'].str.strip().str.lower()
    mongo_df['Title'] = mongo_df['Title'].str.strip().str.lower()
    
    # Merge DataFrames
    merged_df = pd.merge(pdf_df, mongo_df, left_on='file_name', right_on='Title')
    columns_keep = ['file_name', 'ID', 'Year']
    final_df = merged_df[columns_keep]
    final_df = final_df.sort_values(by='Year')
    
    # Define sliding window function
    def get_sliding_window(year):
        start_year = (year // 2) * 2
        return f"{start_year}-{start_year + 2}"
    
    # Apply sliding window function
    final_df['Sliding_year'] = final_df['Year'].apply(get_sliding_window)
    
    return final_df

# %%
folder_path = r'C:\Users\0132499s\Documents\Documents\Transcript\test'
db_url = 'mongodb://localhost:27017/'
db_name = 'foodsystems'
collection_name = 'document_metadata'

files_with_year = extract_year_pdf_files(folder_path, db_url, db_name, collection_name)
print(files_with_year)
# Out:
#                                      file_name   ID  Year Sliding_year
# 0  seanad éireann debate - monday, 21 jun 2021  425  2021    2020-2022

# %% [markdown]
# ### Extract file data
#
# #### Extracting File data by parsing each file from the folder and applying another method extract_speaker_text to extract individual speaker and their corresponding texts.

# %%
def all_document(root_folder):
    all_data = []
    
    # Recursively traverse through all subfolders
    for root, dirs, files in os.walk(root_folder):
        for filename in files:
            if filename.endswith('.pdf'):
                pdf_path = os.path.join(root, filename)
                extracted_data_index = extract_topics_from_index(pdf_path)
                final_topics, normalized_topics, line_breaks, up_to_line_break_final, normalized_up_to_line_break = zip(*extracted_data_index)
                df = extract_speaker_text(pdf_path, speaker_titles, final_topics, normalized_topics)
                #df = extract_speaker_text(pdf_path, speaker_titles, final_topics, normalized_topics, line_breaks, up_to_line_break_final, normalized_up_to_line_break)
                category = os.path.basename(root)  # Get the subfolder name as category
                df['Category'] = category  # Add the category column
                all_data.append(df)
    
    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(all_data, ignore_index=True)
    return combined_df

# %% [markdown]
# #### Merging the year categories dataframe with the extracted Speaker and Text dataframe, in order to categorise each speaker speeach and thier texts in two-year intervals.

# %%
def merge_text_year(text_df, year_df):
    text_df['file_name'] = text_df['file_name'].str.lower()
    combined_df = year_df.merge(text_df, right_on = 'file_name', left_on = 'file_name')
    return combined_df

# %% [markdown]
# #### Compiling a list of titles with which the names of speakers starts. This list will be used in extract_speaker_text function to extract the names of the speakers. The string matching will start from these titles and will end at :, which will comprise of the complete name of the Speaker.

# %%
speaker_titles = ['Chairman',
'Dr.',
'Mr.',
'Minister',
'Deputy',
'Ms',
'An Leas-Cheann Comhairle',
'Acting Chairman',
'An Ceann Comhairle',
'Senator',
'Co-Chairman',
'An Cathaoirleach',
'An Leas-Chathaoirleach',
'Acting Chairperson',
'Professor',
'Vice',
'Clerk',
'Deputies',
'Comptroller',
'Audit',
'General',
'The Taoiseach',
'(Deputy',
'The Tánaiste']

# %% [markdown]
# ### Extracting the topics from the first page

# %%
def normalize_text(text):
    # Remove all spaces and newlines for comparison purposes
    return re.sub(r'\s+', '', text).strip()

def extract_topics_from_index(pdf_path):
    doc = fitz.open(pdf_path)
    first_page_text = doc[0].get_text("text")
    
    # Updated regex pattern to capture topics correctly, including apostrophes and handling line breaks
    index_pattern = re.compile(r"\d{2}/\d{2}/\d{4}[A-Z0-9]*\d+\s*(.+?)(?=\s+\d{2}/\d{2}/\d{4}|$)", re.DOTALL)
    topics = index_pattern.findall(first_page_text)
    
    # Cleaning and formatting the extracted topics
    def clean_topic(topic):
        topic = re.sub(r'[^A-Za-zÁáÉéÍíÓóÚú0-9\s\-\(\)\[\]:,\'’]', '', topic).strip()
        topic = re.sub(r'(?<=\D)(?=\d)', ' ', topic)
        topic = re.sub(r'\s*\d+\s*$', '', topic).strip()  # Remove trailing page numbers
        topic = re.sub(r'\s+', ' ', re.sub(r'(?<=\w)-\s+(?=\d)', '-', topic))
        return topic
    
    cleaned_topics = [clean_topic(topic) for topic in topics]
    final_topics = [clean_topic(topic) for topic in cleaned_topics]
    
    # Normalize the topics for comparison
    normalized_topics = [normalize_text(topic) for topic in final_topics]
    
    # Determine if a topic has a line break and extract the string up until the line break
    line_breaks = [1 if '\n' in topic else 0 for topic in topics]
    up_to_line_break = [topic.split('\n')[0] if '\n' in topic else topic for topic in topics]
    up_to_line_break_final = [clean_topic(topic) for topic in up_to_line_break]
    normalized_up_to_line_break = [normalize_text(topic) for topic in up_to_line_break_final]

    return list(zip(final_topics, normalized_topics, line_breaks, up_to_line_break_final, normalized_up_to_line_break))

# %%
pdf_p = r'C:\Users\0132499s\Documents\Documents\Transcript\test\Seanad Éireann debate - Monday, 21 Jun 2021.pdf'
topics = extract_topics_from_index(pdf_p)
print(topics)
topics_df =pd.DataFrame(topics)
# Out:
# [('Gnó an tSeanaid - Business of Seanad', 'GnóantSeanaid-BusinessofSeanad', 0, 'Gnó an tSeanaid - Business of Seanad', 'GnóantSeanaid-BusinessofSeanad'), ('Nithe i dtosach suíonna - Commencement Matters', 'Nitheidtosachsuíonna-CommencementMatters', 0, 'Nithe i dtosach suíonna - Commencement Matters', 'Nitheidtosachsuíonna-CommencementMatters'), ('Travel Documents', 'TravelDocuments', 0, 'Travel Documents', 'TravelDocuments'), ('School Accommodation', 'SchoolAccommodation', 0, 'School Accommodation', 'SchoolAccommodation'), ('Job Creation', 'JobCreation', 0, 'Job Creation', 'JobCreation'), ('Pharmacy Services', 'PharmacyServices', 0, 'Pharmacy Services', 'PharmacyServices'), ('Employment Support Services', 'EmploymentSupportServices', 0, 'Employment Support Services', 'EmploymentSupportServices'), ('Defence Forces', 'DefenceForces', 0, 'Defence Forces', 'DefenceForces'), ('Gnó an tSeanaid - Business of Seanad', 'GnóantSeanaid-BusinessofSeanad', 0, 'Gnó an tSeanaid - Business of Seanad', 'GnóantSeanaid-BusinessofSeanad'), ('An tOrd Gnó - Order of Business', 'AntOrdGnó-OrderofBusiness', 0, 'An tOrd Gnó - Order of Business', 'AntOrdGnó-OrderofBusiness'), ('Planning and Development (Solar Panels for Public Buildings, Schools, Homes and Other Premises) (Amend ment) Bill 2021: First Stage', 'PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amendment)Bill2021:FirstStage', 1, 'Planning and Development (Solar Panels for Public Buildings, Schools, Homes and Other Premises) (Amend', 'PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend'), ('Eleventh Report of Committee on Parliamentary Privileges and Oversight: Motion', 'EleventhReportofCommitteeonParliamentaryPrivilegesandOversight:Motion', 0, 'Eleventh Report of Committee on Parliamentary Privileges and Oversight: Motion', 'EleventhReportofCommitteeonParliamentaryPrivilegesandOversight:Motion'), ('Climate Action and Low Carbon Development (Amendment) Bill 2021: Second Stage', 'ClimateActionandLowCarbonDevelopment(Amendment)Bill2021:SecondStage', 0, 'Climate Action and Low Carbon Development (Amendment) Bill 2021: Second Stage', 'ClimateActionandLowCarbonDevelopment(Amendment)Bill2021:SecondStage'), ('Aviation Sector: Statements', 'AviationSector:Statements', 0, 'Aviation Sector: Statements', 'AviationSector:Statements'), ('Gender Pay Gap Information Bill 2019: Committee Stage', 'GenderPayGapInformationBill2019:CommitteeStage', 0, 'Gender Pay Gap Information Bill 2019: Committee Stage', 'GenderPayGapInformationBill2019:CommitteeStage')]

# %%
s = 'Covid- 19 Pandemic'
print(s.split)
# Out:
# <built-in method split of str object at 0x00000276EDB08870>

# %%
def normalize_text(text):
    return re.sub(r'\s+', ' ', text).strip()

t = '''
Circular Economy, Waste Management (Amendment) and Minerals Development 
(Amendment) Bill 2022: Referral to Select Committee
'''
t2 = 'Circular Economy Waste Management (Amendment) and Minerals Development (Amendment) Bill 2022: Re ferral to Select Committee'
print(normalize_text(t))
print(normalize_text(t2))
# Out:
# Circular Economy, Waste Management (Amendment) and Minerals Development (Amendment) Bill 2022: Referral to Select Committee
# Circular Economy Waste Management (Amendment) and Minerals Development (Amendment) Bill 2022: Re ferral to Select Committee

# %% [markdown]
# #### Extracting the Speaker and their texts from the PDF files.

# %%
def extract_speaker_text(pdf_path, speaker_titles, topics, normalized_topics):
    data = []
    speaker_pattern = re.compile(r"^\s*(" + "|".join(re.escape(title) for title in speaker_titles) + r")\s*[^:]*:")
    unwanted_pattern1 = re.compile(r"\d{2}/\d{2}/\d{4}[A-Z0-9]*\d(?=[A-Za-z.])")
    unwanted_pattern2 = re.compile(r"\d{2}/\d{2}/\d{4}[A-Z0-9]*\s*\d+")
    time_pattern = re.compile(r"\b\d{1,2} o’clock\b", re.IGNORECASE)
    attached_time_pattern = re.compile(r"(\w*)\d{1,2} o’clock(\w*)", re.IGNORECASE)
    current_topic = None
    file_name = os.path.splitext(os.path.basename(pdf_path))[0]
    pending_speaker = None
    pending_speech = ""

    doc = fitz.open(pdf_path)
    for page_num, page in enumerate(doc, start=1):
        text = page.get_text("text")
        text = time_pattern.sub("", text)
        text = attached_time_pattern.sub(lambda m: (m.group(1) or '') + (m.group(2) or ''), text)
        lines = text.split('\n')

        for i, line in enumerate(lines):
            line = unwanted_pattern1.sub("", line).strip()
            line = unwanted_pattern2.sub("", line).strip()
            normalized_line = normalize_text(line)
            for original_topic, normalized_topic in zip(topics, normalized_topics):
                if normalized_line == normalized_topic:
                    if pending_speaker:
                        pending_speech = unwanted_pattern1.sub("", pending_speech).strip()
                        pending_speech = unwanted_pattern2.sub("", pending_speech).strip()
                        data.append({"file_name": file_name, "Topic": current_topic, "Speaker": pending_speaker, "Exact Text": pending_speech})
                        pending_speaker = None
                        pending_speech = ""
                    current_topic = original_topic
                    break
            else:
                match = speaker_pattern.match(line)
                if match:
                    if pending_speaker:
                        pending_speech = unwanted_pattern1.sub("", pending_speech).strip()
                        pending_speech = unwanted_pattern2.sub("", pending_speech).strip()
                        data.append({"file_name": file_name, "Topic": current_topic, "Speaker": pending_speaker, "Exact Text": pending_speech})
                    pending_speaker = match.group().strip(":")
                    pending_speech = line.split(":", 1)[1].strip()
                else:
                    if pending_speaker:
                        pending_speech += " " + line.strip()
                    else:
                        if i + 1 < len(lines) and lines[i + 1].strip().startswith("("):
                            line += " " + lines[i + 1].strip()
                            match = speaker_pattern.match(line)
                            if match:
                                pending_speaker = match.group().strip(":")
                                pending_speech = line.split(":", 1)[1].strip()
                                continue

    if pending_speaker:
        pending_speech = unwanted_pattern1.sub("", pending_speech).strip()
        pending_speech = unwanted_pattern2.sub("", pending_speech).strip()
        data.append({"file_name": file_name, "Topic": current_topic, "Speaker": pending_speaker, "Exact Text": pending_speech.strip()})

    df = pd.DataFrame(data)
    return df

# %%
def test_partial_topic_matching():
    norm_up_to_line_break = 'PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend'
    normalized_line = 'PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,Homesand'
    
    if normalized_line == norm_up_to_line_break[:len(normalized_line)]:
        print("Match found")
    else:
        print("No match found")

test_partial_topic_matching()
# Out:
# Match found

# %%
import re

# Updated regex pattern to handle no space between date and following text
unwanted = re.compile(r"\d{2}/\d{2}/\d{4}[A-Z0-9]*\d+")

l1 = '''
2 p.m. 5/07/2015Y00100Events at Ballymurphy in 1971 and Legacy Issues: '''
line = unwanted.sub("", l1).strip()
print(line)
# Out:
# 2 p.m. 5/07/2015Y00100Events at Ballymurphy in 1971 and Legacy Issues:

# %% [markdown]
# ### Data Pre-Processing and Cleaning
#
# #### Remove Header and Footer from each page. Each page contains either Date or Abbrevaited Department Name as Header and Page Number as Footer.

# %%
headers = ['Dáil Éireann']

# %%
def remove_header_footer(text, headers):
    # Create a regex pattern to match any string from the headers list and dates
    header_pattern = r"(" + "|".join(re.escape(header) for header in headers) + r")"
    date_pattern = r"\d{1,2}\s+(January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{4}"
    page_number_pattern = r"\d+"

    combined_pattern = re.compile(
        rf"(\s*{header_pattern}\s*{page_number_pattern}\s*|\s*{page_number_pattern}\s*{header_pattern}\s*|\s*{date_pattern}\s*{page_number_pattern}\s*|\s*{page_number_pattern}\s*{date_pattern}\s*)", re.IGNORECASE
    )
    
    cleaned_text = combined_pattern.sub(" ", text)
    return cleaned_text

    
text = 'public health nurse who will do an assessment and make a referral for 29 November 2023 613 the vital home care supports. e well educated and enthusiastic about their job. They are finding Dáil Éireann 614 a huge impediment getting a place to live in the areas we are talking about.'
cleaned_text = remove_header_footer(text, headers)
print(cleaned_text)
# Out:
# public health nurse who will do an assessment and make a referral for the vital home care supports. e well educated and enthusiastic about their job. They are finding a huge impediment getting a place to live in the areas we are talking about.

# %% [markdown]
# #### Removing Stopwords from the text.

# %%
stop_words = set(stopwords.words('english'))

def remove_stop_words(text):
    words = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

t = 'correspondence committee meeting agreed department item dated note members public ask information matter week witnesses audir regarding publish statements clerk secretary session NAMA issues issue accounts propose minutes HSE local education financial board published county received requested day make hear housing letter come respect june want items meetings matters individual proposed discussion april questions privilege chief school follow 2017 deal'
print(remove_stop_words(t))
# Out:
# correspondence committee meeting agreed department item dated note members public ask information matter week witnesses audir regarding publish statements clerk secretary session NAMA issues issue accounts propose minutes HSE local education financial board published county received requested day make hear housing letter come respect june want items meetings matters individual proposed discussion april questions privilege chief school follow 2017 deal

# %% [markdown]
# #### Removing the grammer terms; Personal and Possesive Nouns, Verb, Adjectives, Adverbs, Preposition, Conjunction, Interjection, Determiner, Pronouns. Keeping everything else from the text, which should include mostly Nouns, numbers and some other words which remained untagged.

# %%
def extract_grammer(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    remove_pos = ['PRP', 'PRP$', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS', 'RB', 'RBR', 'RBS','IN', 'CC', 'UH', 'DT', 'PDT', 'WDT', 'WP', 'WP$', 'WRB']
    filtered_words = [word for word, pos in tagged_words if pos not in remove_pos]
    return ' '.join(filtered_words)
    #return tagged_words

t = 'correspondence committee meeting agreed department item dated note members public ask information matter week witnesses audir regarding publish statements clerk secretary session NAMA issues issue accounts propose minutes HSE local education financial board published county received requested day make hear housing letter come respect june want items meetings matters individual proposed discussion april questions privilege chief school follow 2017 deal'
print(extract_grammer(t))
# Out:
# correspondence committee department item members information matter week witnesses statements secretary session NAMA issues issue accounts minutes HSE education board day housing letter respect june items meetings matters discussion april questions school 2017 deal

# %% [markdown]
# #### Remove words with just two or less letters. As well as, sentences with less than five words. Since, in both these cases, the words / sentences are not very informative.

# %%
def remove_two_letter_words(text):
    return ' '.join(word for word in text.split() if len(word) > 2)
                    
def remove_line_less_than_five(df):
    def word_count(text):
        return len(text.split())
        
    df['Text'] = df['Text'].apply(remove_two_letter_words)
        
    filtered_df = df[df['Text'].apply(word_count) > 5]
    return filtered_df

# %% [markdown]
# #### Removing commas, special characters with commas, and extra spaces.

# %%
def remove_special_char(text):
    # Remove commas
    cleaned_text = text.replace(',', '')
    # Replace special characters with blank spaces
    cleaned_text = re.sub(r'[^A-Za-z0-9\s]', ' ', cleaned_text)
    # Remove extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

t = 'correspondence committee meeting agreed department item dated note members public ask information matter week witnesses audir regarding publish statements clerk secretary session NAMA issues issue accounts propose minutes HSE local education financial board published county received requested day make hear housing letter come respect june want items meetings matters individual proposed discussion april questions privilege chief school follow 2017 deal'
print(remove_special_char(t))
# Out:
# correspondence committee meeting agreed department item dated note members public ask information matter week witnesses audir regarding publish statements clerk secretary session NAMA issues issue accounts propose minutes HSE local education financial board published county received requested day make hear housing letter come respect june want items meetings matters individual proposed discussion april questions privilege chief school follow 2017 deal

# %% [markdown]
# #### Removing extra spaces and numbers, since they are not very informative without context.

# %%
def remove_extra_spaces_and_numbers(text):
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\b\w\b', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

t = 'cember 5 30 p m agenda examation update eradication TB may meetg Wednesday morng new CBF classifications confirmed likely jot committee adjourned 8 50 p m 5 30 p m W'
print(remove_extra_spaces_and_numbers(t))
# Out:
# cember agenda examation update eradication TB may meetg Wednesday morng new CBF classifications confirmed likely jot committee adjourned

# %% [markdown]
# #### Remove names of speakers from the final text, since they are just addressing each other in a dialog and it is non-informative.

# %%
def remove_speaker_words(df):
    all_speaker_words = set(speaker_titles)
    for speaker_name in df['Speaker']:
        speaker_words = speaker_name.split()
        all_speaker_words.update(speaker_words)
    print(f"All speaker words :{all_speaker_words}")
    for index, row in df.iterrows():
        text = row['Text']
        for word in all_speaker_words:
            text = text.replace(word, '')
        df.at[index, 'Text'] = text.strip()
    return df

# %% [markdown]
# #### A function to detect the language of a piece of text, since some of the texts are available in Irish.

# %%
def detect_language(text):
    try:
        lang = detect(text)
        return 'Irish' if lang == 'ga' else 'English'
    except:
        return 'Unknown'

# %% [markdown]
# ### Extracting all the texts from all the PDF files in one go and storing all the data in a dataframe, df_with_text.

# %%
df_with_text = all_document(folder_path)
print(df_with_text.shape)
print(df_with_text)
# Out:
# (302, 5)
#                                        file_name  \
# 0    Seanad Éireann debate - Monday, 21 Jun 2021
# 1    Seanad Éireann debate - Monday, 21 Jun 2021
# 2    Seanad Éireann debate - Monday, 21 Jun 2021
# 3    Seanad Éireann debate - Monday, 21 Jun 2021
# 4    Seanad Éireann debate - Monday, 21 Jun 2021
# ..                                           ...
# 297  Seanad Éireann debate - Monday, 21 Jun 2021
# 298  Seanad Éireann debate - Monday, 21 Jun 2021
# 299  Seanad Éireann debate - Monday, 21 Jun 2021
# 300  Seanad Éireann debate - Monday, 21 Jun 2021
# 301  Seanad Éireann debate - Monday, 21 Jun 2021
#
#                                                  Topic  \
# 0                 Gnó an tSeanaid - Business of Seanad
# 1                                     Travel Documents
# 2                                     Travel Documents
# 3                                     Travel Documents
# 4                                 School Accommodation
# ..                                                 ...
# 297  Gender Pay Gap Information Bill 2019: Committe...
# 298  Gender Pay Gap Information Bill 2019: Committe...
# 299  Gender Pay Gap Information Bill 2019: Committe...
# 300  Gender Pay Gap Information Bill 2019: Committe...
# 301  Gender Pay Gap Information Bill 2019: Committe...
#
#                          Speaker  \
# 0               An Cathaoirleach
# 1        Senator  Regina Doherty
# 2        Senator  Regina Doherty
# 3           Deputy  Ossian Smyth
# 4             Senator  Seán Kyne
# ..                           ...
# 297       An Leas-Chathaoirleach
# 298  Senator  Mary Seery Kearney
# 299       An Leas-Chathaoirleach
# 300       An Leas-Chathaoirleach
# 301  Senator  Mary Seery Kearney
#
#                                             Exact Text Category
# 0    I have received notice from Senator Regina Doh...     test
# 1    I thank the Minister of State for his attendan...     test
# 2    I thank the Minister of State.  Respectfully, ...     test
# 3    First, the Senator asked how people apply.  In...     test
# 4    I thank the Cathaoirleach’s office for choosin...     test
# ..                                                 ...      ...
# 297          When is it proposed to take Report Stage?     test
# 298                           On Friday, 25 June 2021.     test
# 299  Is that agreed?  Agreed. Report Stage ordered ...     test
# 300                  When is it proposed to sit again?     test
# 301  Tomorrow morning at 9 a.m. in the convention c...     test
#
# [302 rows x 5 columns]

# %%
distinct_topics = df_with_text['Topic'].unique()
print(distinct_topics)
# Out:
# ['Gnó an tSeanaid - Business of Seanad' 'Travel Documents'
#  'School Accommodation' 'Job Creation' 'Pharmacy Services'
#  'Employment Support Services' 'Defence Forces'
#  'An tOrd Gnó - Order of Business'
#  'Eleventh Report of Committee on Parliamentary Privileges and Oversight: Motion'
#  'Climate Action and Low Carbon Development (Amendment) Bill 2021: Second Stage'
#  'Aviation Sector: Statements'
#  'Gender Pay Gap Information Bill 2019: Committee Stage']

# %%
def save_to_excel(df, excel_path):
    df.to_excel(excel_path, index=False)

excel_path_separate = r'C:\Users\0132499s\Documents\Documents\Transcript\test\text.xlsx'

save_to_excel(df_with_text, excel_path_separate)

# %%
def normalize_text(text):
    # Remove all spaces and newlines for comparison purposes
    return re.sub(r'\s+', '', text).strip()

def update_topics_with_normalization(df, topics_df):
    # Filter topics_df to only include rows where line_break is 1
    filtered_topics_df = topics_df[topics_df[2] == 1]
    print(str(filtered_topics_df[4]))
    # Iterate through each row in the DataFrame
    for i in range(len(df)):
        # Split the Exact Text into separate lines
        lines = df.at[i, 'Exact Text'].split('. ')
        for line in lines:
            normalized_line = normalize_text(line)
            print(f"LINE: {line}, NORMALIZED: {normalized_line}")
            # Check if the normalized line matches the start of any normalized topic
            for norm_up_to_line_break in filtered_topics_df[4]:
                print(f"NORMALIZED TOPIC: {norm_up_to_line_break}, NORMALIZED: {normalized_line}")
                if normalized_line == norm_up_to_line_break[:len(normalized_line)]:
                    print('norm_up_to_line_break: ',norm_up_to_line_break)
                    # Remove the partial topic from the Exact Text
                    df.at[i, 'Exact Text'] = df.at[i, 'Exact Text'].replace(line, '').strip()
                    # Update the Topic for subsequent rows until a new topic is encountered
                    partial_topic = line.strip()
                    for j in range(i + 1, len(df)):
                        if df.at[j, 'Topic'] == '':
                            df.at[j, 'Topic'] = partial_topic
                        else:
                            break
                    break
    return df

# %%
PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amendment)Bill2021
PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend

# %%
updated_df = update_topics_with_normalization(df_with_text, topics_df)
print(updated_df)
# Out:
# 10    PlanningandDevelopment(SolarPanelsforPublicBui...
# Name: 4, dtype: object
# LINE: I have received notice from Senator Regina Doherty that, on the motion for the Commencement of the House today, she proposes to raise the following matter: The need for the Minister of State with responsibility for public procurement and eGov­ ernment to outline his plan for the implementation and operation of the EU digital Covid certificate in Ireland, NORMALIZED: IhavereceivednoticefromSenatorReginaDohertythat,onthemotionfortheCommencementoftheHousetoday,sheproposestoraisethefollowingmatter:TheneedfortheMinisterofStatewithresponsibilityforpublicprocurementandeGov­ernmenttooutlinehisplanfortheimplementationandoperationoftheEUdigitalCovidcertificateinIreland
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IhavereceivednoticefromSenatorReginaDohertythat,onthemotionfortheCommencementoftheHousetoday,sheproposestoraisethefollowingmatter:TheneedfortheMinisterofStatewithresponsibilityforpublicprocurementandeGov­ernmenttooutlinehisplanfortheimplementationandoperationoftheEUdigitalCovidcertificateinIreland
# LINE: I have also received notice from Senator Seán Kyne of the following matter: The need for the Minister for Education to provide an update on a new school building for Scoil Náisiúnta Shéamais Naofa, Bearna, Contae na Gaillimhe, NORMALIZED: IhavealsoreceivednoticefromSenatorSeánKyneofthefollowingmatter:TheneedfortheMinisterforEducationtoprovideanupdateonanewschoolbuildingforScoilNáisiúntaShéamaisNaofa,Bearna,ContaenaGaillimhe
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IhavealsoreceivednoticefromSenatorSeánKyneofthefollowingmatter:TheneedfortheMinisterforEducationtoprovideanupdateonanewschoolbuildingforScoilNáisiúntaShéamaisNaofa,Bearna,ContaenaGaillimhe
# LINE: I have also received notice from Senator Paul Gavan of the following matter: The need for the Tánaiste and Minister for Enterprise, Trade and Employment to outline his plans to address the challenges of long-term unemployment black spots in Limerick, NORMALIZED: IhavealsoreceivednoticefromSenatorPaulGavanofthefollowingmatter:TheneedfortheTánaisteandMinisterforEnterprise,TradeandEmploymenttooutlinehisplanstoaddressthechallengesoflong-termunemploymentblackspotsinLimerick
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IhavealsoreceivednoticefromSenatorPaulGavanofthefollowingmatter:TheneedfortheTánaisteandMinisterforEnterprise,TradeandEmploymenttooutlinehisplanstoaddressthechallengesoflong-termunemploymentblackspotsinLimerick
# LINE: I have also received notice from Senator Sharon Keogan of the following matter: The need for the Minister for Health to make a statement on the roll-out of a minor ail­ ment scheme through the national network of pharmacies, NORMALIZED: IhavealsoreceivednoticefromSenatorSharonKeoganofthefollowingmatter:TheneedfortheMinisterforHealthtomakeastatementontheroll-outofaminorail­mentschemethroughthenationalnetworkofpharmacies
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IhavealsoreceivednoticefromSenatorSharonKeoganofthefollowingmatter:TheneedfortheMinisterforHealthtomakeastatementontheroll-outofaminorail­mentschemethroughthenationalnetworkofpharmacies
# LINE: I have also received notice from Senator Erin McGreehan of the following matter: The need for the Minister for Social Protection to extend the reasonable accommodation fund to public sector employees, NORMALIZED: IhavealsoreceivednoticefromSenatorErinMcGreehanofthefollowingmatter:TheneedfortheMinisterforSocialProtectiontoextendthereasonableaccommodationfundtopublicsectoremployees
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED:
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: OfthemattersraisedbytheSenatorssuitablefordiscussion,IhaveselectedSenatorsDoherty,Kyne,Keogan,Gavan,McGreehanandCroweandtheywillbetakennow
# LINE:  I regret that I have had to rule out of order the matter raised by Senator Cassells on the ground that the Minister has no official responsibility in the matter, NORMALIZED: IregretthatIhavehadtoruleoutoforderthematterraisedbySenatorCassellsonthegroundthattheMinisterhasnoofficialresponsibilityinthematter
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IregretthatIhavehadtoruleoutoforderthematterraisedbySenatorCassellsonthegroundthattheMinisterhasnoofficialresponsibilityinthematter
# LINE:  The other Senators may give notice on another day of the matters they wish to raise., NORMALIZED: TheotherSenatorsmaygivenoticeonanotherdayofthematterstheywishtoraise.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheotherSenatorsmaygivenoticeonanotherdayofthematterstheywishtoraise.
# LINE: I thank the Minister of State for his attendance in the House this morning to discuss this matter, NORMALIZED: IthanktheMinisterofStateforhisattendanceintheHousethismorningtodiscussthismatter
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IthanktheMinisterofStateforhisattendanceintheHousethismorningtodiscussthismatter
# LINE:  I wish to raise the importance of Ireland’s implementation of the EU digital Covid certificate, or what we used to call the EU green certificate, NORMALIZED: IwishtoraisetheimportanceofIreland’simplementationoftheEUdigitalCovidcertificate,orwhatweusedtocalltheEUgreencertificate
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IwishtoraisetheimportanceofIreland’simplementationoftheEUdigitalCovidcertificate,orwhatweusedtocalltheEUgreencertificate
# LINE:  As we are all aware, the Government has signed up to the EU Covid certificate with a start date of July 19, albeit two weeks later than the rest of our European colleagues, NORMALIZED: Asweareallaware,theGovernmenthassigneduptotheEUCovidcertificatewithastartdateofJuly19,albeittwoweekslaterthantherestofourEuropeancolleagues
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Asweareallaware,theGovernmenthassigneduptotheEUCovidcertificatewithastartdateofJuly19,albeittwoweekslaterthantherestofourEuropeancolleagues
# LINE:  The certificate has been devel­ oped by the EU Commission over the last six months under their plan entitled “A common path to a safe and sustained re-opening”, NORMALIZED: Thecertificatehasbeendevel­opedbytheEUCommissionoverthelastsixmonthsundertheirplanentitled“Acommonpathtoasafeandsustainedre-opening”
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Thecertificatehasbeendevel­opedbytheEUCommissionoverthelastsixmonthsundertheirplanentitled“Acommonpathtoasafeandsustainedre-opening”
# LINE:  The importance of reopening our skies and gaining back our crucial connectivity cannot be understated, NORMALIZED: Theimportanceofreopeningourskiesandgainingbackourcrucialconnectivitycannotbeunderstated
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Theimportanceofreopeningourskiesandgainingbackourcrucialconnectivitycannotbeunderstated
# LINE:  Hundreds of thousands of families are relying on us to get this reopening right, NORMALIZED: Hundredsofthousandsoffamiliesarerelyingonustogetthisreopeningright
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Hundredsofthousandsoffamiliesarerelyingonustogetthisreopeningright
# LINE:  Therefore, it must be both safe and easy, and we must get unhindered access to travel, NORMALIZED: Therefore,itmustbebothsafeandeasy,andwemustgetunhinderedaccesstotravel
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Therefore,itmustbebothsafeandeasy,andwemustgetunhinderedaccesstotravel
# LINE: When we talk about the reopening of travel, it is often inaccurately framed, either in the media or on our social media, as involving young people who are desperate to head off to Ibiza, NORMALIZED: Whenwetalkaboutthereopeningoftravel,itisofteninaccuratelyframed,eitherinthemediaoronoursocialmedia,asinvolvingyoungpeoplewhoaredesperatetoheadofftoIbiza
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED:
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Sometimes,ideasstarttofloataroundandneedtobeclarifiedsoIthanktheSenatorforbringingthisissuetotheattentionoftheHouse
# LINE:  I always welcome the oppor­ tunity to speak in the Seanad, NORMALIZED: Ialwayswelcometheoppor­tunitytospeakintheSeanad
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Ialwayswelcometheoppor­tunitytospeakintheSeanad
# LINE:  Seanad Éireann 250 As the Senator is aware, an EU digital Covid certificate is digital proof that a person has been vaccinated against Covid-19, has received a negative test result or has recovered from Co­ vid-19, NORMALIZED: SeanadÉireann250AstheSenatorisaware,anEUdigitalCovidcertificateisdigitalproofthatapersonhasbeenvaccinatedagainstCovid-19,hasreceivedanegativetestresultorhasrecoveredfromCo­vid-19
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: SeanadÉireann250AstheSenatorisaware,anEUdigitalCovidcertificateisdigitalproofthatapersonhasbeenvaccinatedagainstCovid-19,hasreceivedanegativetestresultorhasrecoveredfromCo­vid-19
# LINE:  There are three separate certificates for those three events, NORMALIZED: Therearethreeseparatecertificatesforthosethreeevents
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Therearethreeseparatecertificatesforthosethreeevents
# LINE:  Being in receipt of an EU digital Covid certificate should enable the holder to be exempt from restrictions on freedom of movement, NORMALIZED: BeinginreceiptofanEUdigitalCovidcertificateshouldenabletheholdertobeexemptfromrestrictionsonfreedomofmovement
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: BeinginreceiptofanEUdigitalCovidcertificateshouldenabletheholdertobeexemptfromrestrictionsonfreedomofmovement
# LINE:  However, member states do have the right to impose additional travel restrictions on the holders of an EU digital Covid certificate provided they are necessary and proportionate to safeguard public health, NORMALIZED: However,memberstatesdohavetherighttoimposeadditionaltravelrestrictionsontheholdersofanEUdigitalCovidcertificateprovidedtheyarenecessaryandproportionatetosafeguardpublichealth
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: However,memberstatesdohavetherighttoimposeadditionaltravelrestrictionsontheholdersofanEUdigitalCovidcertificateprovidedtheyarenecessaryandproportionatetosafeguardpublichealth
# LINE:  In such a case, as a reaction to new variants of concern, the member state would have to notify the Commission and all other member states to justify this decision, NORMALIZED: Insuchacase,asareactiontonewvariantsofconcern,thememberstatewouldhavetonotifytheCommissionandallothermemberstatestojustifythisdecision
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Insuchacase,asareactiontonewvariantsofconcern,thememberstatewouldhavetonotifytheCommissionandallothermemberstatestojustifythisdecision
# LINE: Each country will be responsible for issuing certificates where vaccination, a positive test for recovery or a negative test has taken place in that country, NORMALIZED: Eachcountrywillberesponsibleforissuingcertificateswherevaccination,apositivetestforrecoveryoranegativetesthastakenplaceinthatcountry
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Eachcountrywillberesponsibleforissuingcertificateswherevaccination,apositivetestforrecoveryoranegativetesthastakenplaceinthatcountry
# LINE: In Ireland, the Government recognises how stretched the HSE is in terms of trying to sup­ port the vaccination roll-out and business as usual while recovering from the damage caused by the recent ransomware attack, NORMALIZED: InIreland,theGovernmentrecogniseshowstretchedtheHSEisintermsoftryingtosup­portthevaccinationroll-outandbusinessasusualwhilerecoveringfromthedamagecausedbytherecentransomwareattack
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: InIreland,theGovernmentrecogniseshowstretchedtheHSEisintermsoftryingtosup­portthevaccinationroll-outandbusinessasusualwhilerecoveringfromthedamagecausedbytherecentransomwareattack
# LINE:  Consequently, we are looking at how we can best support the HSE with these new obligations, NORMALIZED: Consequently,wearelookingathowwecanbestsupporttheHSEwiththesenewobligations
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Consequently,wearelookingathowwecanbestsupporttheHSEwiththesenewobligations
# LINE:  For example, the Department of Public Expenditure and Reform, through the Office of the Government Chief Information Officer, is working with the private sector to develop the system to support the negative test certificates so we will be issu­ ing those certificates to say that a person has tested negative in the previous three days, NORMALIZED: Forexample,theDepartmentofPublicExpenditureandReform,throughtheOfficeoftheGovernmentChiefInformationOfficer,isworkingwiththeprivatesectortodevelopthesystemtosupportthenegativetestcertificatessowewillbeissu­ingthosecertificatestosaythatapersonhastestednegativeinthepreviousthreedays
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Forexample,theDepartmentofPublicExpenditureandReform,throughtheOfficeoftheGovernmentChiefInformationOfficer,isworkingwiththeprivatesectortodevelopthesystemtosupportthenegativetestcertificatessowewillbeissu­ingthosecertificatestosaythatapersonhastestednegativeinthepreviousthreedays
# LINE:  How­ ever, the Department of Health and the HSE are responsible for issuing vaccination certificates and recovery certificates, NORMALIZED: How­ever,theDepartmentofHealthandtheHSEareresponsibleforissuingvaccinationcertificatesandrecoverycertificates
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: How­ever,theDepartmentofHealthandtheHSEareresponsibleforissuingvaccinationcertificatesandrecoverycertificates
# LINE: The EU digital Covid certificate contains only the necessary key information such as name, date of birth, date of issuance, relative information about vaccine test or recovery and a unique identifier, NORMALIZED: TheEUdigitalCovidcertificatecontainsonlythenecessarykeyinformationsuchasname,dateofbirth,dateofissuance,relativeinformationaboutvaccinetestorrecoveryandauniqueidentifier
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheEUdigitalCovidcertificatecontainsonlythenecessarykeyinformationsuchasname,dateofbirth,dateofissuance,relativeinformationaboutvaccinetestorrecoveryandauniqueidentifier
# LINE:  This data remains on the certificate and is not stored or retained when a certificate is verified in another member state, NORMALIZED: Thisdataremainsonthecertificateandisnotstoredorretainedwhenacertificateisverifiedinanothermemberstate
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Thisdataremainsonthecertificateandisnotstoredorretainedwhenacertificateisverifiedinanothermemberstate
# LINE:  For verification purposes, only the validity and authentic­ ity of the certificate is checked by the person verifying it who issued and signed it, NORMALIZED: Forverificationpurposes,onlythevalidityandauthentic­ityofthecertificateischeckedbythepersonverifyingitwhoissuedandsignedit
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Forverificationpurposes,onlythevalidityandauthentic­ityofthecertificateischeckedbythepersonverifyingitwhoissuedandsignedit
# LINE:  All health data remains with the member state that issued an EU digital Covid certificate, NORMALIZED: AllhealthdataremainswiththememberstatethatissuedanEUdigitalCovidcertificate
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: AllhealthdataremainswiththememberstatethatissuedanEUdigitalCovidcertificate
# LINE:  The system is logical, NORMALIZED: Thesystemislogical
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Thesystemislogical
# LINE:  Each EU digital Covid certificate will contain a quick response, QR, code with a digi­ tal signature to protect against falsification, NORMALIZED: EachEUdigitalCovidcertificatewillcontainaquickresponse,QR,codewithadigi­talsignaturetoprotectagainstfalsification
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: EachEUdigitalCovidcertificatewillcontainaquickresponse,QR,codewithadigi­talsignaturetoprotectagainstfalsification
# LINE:  When the certificate is checked, the QR code is scanned and the signature is verified, NORMALIZED: Whenthecertificateischecked,theQRcodeisscannedandthesignatureisverified
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Whenthecertificateischecked,theQRcodeisscannedandthesignatureisverified
# LINE:  The signature can be checked using special software that can run from an app on a phone or any other device that can read a QR code, NORMALIZED: ThesignaturecanbecheckedusingspecialsoftwarethatcanrunfromanapponaphoneoranyotherdevicethatcanreadaQRcode
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ThesignaturecanbecheckedusingspecialsoftwarethatcanrunfromanapponaphoneoranyotherdevicethatcanreadaQRcode
# LINE: Each issuing body has its own digital signature key that will be securely stored, NORMALIZED: Eachissuingbodyhasitsowndigitalsignaturekeythatwillbesecurelystored
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Eachissuingbodyhasitsowndigitalsignaturekeythatwillbesecurelystored
# LINE:  We are only planning to have one or possibly two for our certificates, NORMALIZED: Weareonlyplanningtohaveoneorpossiblytwoforourcertificates
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Weareonlyplanningtohaveoneorpossiblytwoforourcertificates
# LINE:  The European Commission has built a gateway through which the certificate signatures from each member state can be verified across the EU, NORMALIZED: TheEuropeanCommissionhasbuiltagatewaythroughwhichthecertificatesignaturesfromeachmemberstatecanbeverifiedacrosstheEU
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheEuropeanCommissionhasbuiltagatewaythroughwhichthecertificatesignaturesfromeachmemberstatecanbeverifiedacrosstheEU
# LINE:  It is important to note that the personal data of a certificate owner does not pass through the gateway because this is not necessary to verify the digital signature, NORMALIZED: Itisimportanttonotethatthepersonaldataofacertificateownerdoesnotpassthroughthegatewaybecausethisisnotnecessarytoverifythedigitalsignature
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Itisimportanttonotethatthepersonaldataofacertificateownerdoesnotpassthroughthegatewaybecausethisisnotnecessarytoverifythedigitalsignature
# LINE: EU digital Covid certificates can be stored on mobile devices, although citizens can request paper versions if they need them, NORMALIZED: EUdigitalCovidcertificatescanbestoredonmobiledevices,althoughcitizenscanrequestpaperversionsiftheyneedthem
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: EUdigitalCovidcertificatescanbestoredonmobiledevices,althoughcitizenscanrequestpaperversionsiftheyneedthem
# LINE:  Both versions will have a QR code containing essential information as well as a digital signature to make sure the certificate is authentic, NORMALIZED: BothversionswillhaveaQRcodecontainingessentialinformationaswellasadigitalsignaturetomakesurethecertificateisauthentic
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: BothversionswillhaveaQRcodecontainingessentialinformationaswellasadigitalsignaturetomakesurethecertificateisauthentic
# LINE:  Member states have agreed on a common design that can be used for the electronic and paper versions to facilitate recognition, NORMALIZED: Memberstateshaveagreedonacommondesignthatcanbeusedfortheelectronicandpaperversionstofacilitaterecognition
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Memberstateshaveagreedonacommondesignthatcanbeusedfortheelectronicandpaperversionstofacilitaterecognition
# LINE:  I am pleased to advise that the Irish certificate has been designed and the digital signature has already been tested with the EU, NORMALIZED: IampleasedtoadvisethattheIrishcertificatehasbeendesignedandthedigitalsignaturehasalreadybeentestedwiththeEU
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: IampleasedtoadvisethattheIrishcertificatehasbeendesignedandthedigitalsignaturehasalreadybeentestedwiththeEU
# LINE:  It is important that we stress test the overall process, NORMALIZED: Itisimportantthatwestresstesttheoverallprocess
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Itisimportantthatwestresstesttheoverallprocess
# LINE:  We need to develop the most efficient way to enable travellers to be checked before departing the island and to enable visitors or those returning to be checked on entry to Ireland, NORMALIZED: WeneedtodevelopthemostefficientwaytoenabletravellerstobecheckedbeforedepartingtheislandandtoenablevisitorsorthosereturningtobecheckedonentrytoIreland
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Arewegoingtologontoawebsite?Obviously,thathasnotbeendecidedyet
# LINE:  These are the issues, NORMALIZED: Thesearetheissues
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Thesearetheissues
# LINE:  How will it work?  How will Irish citizens apply for a certificate?  Who will give it to them? The Minister of State alluded to the fact that there will be three certificates, NORMALIZED: Howwillitwork?HowwillIrishcitizensapplyforacertificate?Whowillgiveittothem?TheMinisterofStatealludedtothefactthattherewillbethreecertificates
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Howwillitwork?HowwillIrishcitizensapplyforacertificate?Whowillgiveittothem?TheMinisterofStatealludedtothefactthattherewillbethreecertificates
# LINE:  Will we go to three different places?  Will I go to the HSE to get my vaccination and to the Department of Public Expenditure and Reform to get my digital certificate?  Again, I am not trying to be smart, NORMALIZED: Willwegotothreedifferentplaces?WillIgototheHSEtogetmyvaccinationandtotheDepartmentofPublicExpenditureandReformtogetmydigitalcertificate?Again,Iamnottryingtobesmart
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Willwegotothreedifferentplaces?WillIgototheHSEtogetmyvaccinationandtotheDepartmentofPublicExpenditureandReformtogetmydigitalcertificate?Again,Iamnottryingtobesmart
# LINE: We are trying to give clarity, NORMALIZED: Wearetryingtogiveclarity
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Wearetryingtogiveclarity
# LINE:  I appreciate that he said that it is still at design stage, NORMALIZED: Iappreciatethathesaidthatitisstillatdesignstage
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Iappreciatethathesaidthatitisstillatdesignstage
# ...
# LINE: On amendment No, NORMALIZED: OnamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: OnamendmentNo
# LINE: 44, if the review after four years envisages legislative changes and we still have in place the mechanism set out in this Bill, there is a mechanism for bringing in another review proposal, NORMALIZED: 44,ifthereviewafterfouryearsenvisageslegislativechangesandwestillhaveinplacethemechanismsetoutinthisBill,thereisamechanismforbringinginanotherreviewproposal
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 44,ifthereviewafterfouryearsenvisageslegislativechangesandwestillhaveinplacethemechanismsetoutinthisBill,thereisamechanismforbringinginanotherreviewproposal
# LINE:  That is the best way to go, NORMALIZED: Thatisthebestwaytogo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Thatisthebestwaytogo
# LINE: On the idea of a report, the review we are initiating will address much of that, NORMALIZED: Ontheideaofareport,thereviewweareinitiatingwilladdressmuchofthat
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Ontheideaofareport,thereviewweareinitiatingwilladdressmuchofthat
# LINE:  In looking at the legislation, the review will also look at the bigger questions and the ongoing appropriate­ ness of this legislation in the context of what it has achieved and what it seeks to achieve, NORMALIZED: Inlookingatthelegislation,thereviewwillalsolookatthebiggerquestionsandtheongoingappropriate­nessofthislegislationinthecontextofwhatithasachievedandwhatitseekstoachieve
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Inlookingatthelegislation,thereviewwillalsolookatthebiggerquestionsandtheongoingappropriate­nessofthislegislationinthecontextofwhatithasachievedandwhatitseekstoachieve
# LINE:  To provide for a  report within three years when the initial review will take place within four years would be to take a disjointed approach to gaining a full understanding of how this legislation works, having allowed one full cycle when we it will apply to employers with 50 employees, NORMALIZED: Toprovideforareportwithinthreeyearswhentheinitialreviewwilltakeplacewithinfouryearswouldbetotakeadisjointedapproachtogainingafullunderstandingofhowthislegislationworks,havingallowedonefullcyclewhenweitwillapplytoemployerswith50employees
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Toprovideforareportwithinthreeyearswhentheinitialreviewwilltakeplacewithinfouryearswouldbetotakeadisjointedapproachtogainingafullunderstandingofhowthislegislationworks,havingallowedonefullcyclewhenweitwillapplytoemployerswith50employees
# LINE: Amendment, by leave, withdrawn., NORMALIZED: Amendment,byleave,withdrawn.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Amendment,byleave,withdrawn.
# LINE: I move amendment No, NORMALIZED: ImoveamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ImoveamendmentNo
# LINE: 43: In page 11, line 10, to delete “4th anniversary” and substitute “3rd anniversary”, NORMALIZED: 43:Inpage11,line10,todelete“4thanniversary”andsubstitute“3rdanniversary”
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 43:Inpage11,line10,todelete“4thanniversary”andsubstitute“3rdanniversary”
# LINE: For reasons of consistency, I will press the amendment, NORMALIZED: Forreasonsofconsistency,Iwillpresstheamendment
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Forreasonsofconsistency,Iwillpresstheamendment
# LINE: Amendment put and declared lost., NORMALIZED: Amendmentputanddeclaredlost.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Amendmentputanddeclaredlost.
# LINE: I move amendment No, NORMALIZED: ImoveamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ImoveamendmentNo
# LINE: 44: In page 11, line 11, after “section” to insert “and shall review the same not less than every three years subsequently”, NORMALIZED: 44:Inpage11,line11,after“section”toinsert“andshallreviewthesamenotlessthaneverythreeyearssubsequently”
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 44:Inpage11,line11,after“section”toinsert“andshallreviewthesamenotlessthaneverythreeyearssubsequently”
# LINE: Amendment put and declared lost, NORMALIZED: Amendmentputanddeclaredlost
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Amendmentputanddeclaredlost
# LINE: Section 6 agreed to, NORMALIZED: Section6agreedto
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Section6agreedto
# LINE: NEW SECTION, NORMALIZED: NEWSECTION
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: NEWSECTION
# LINE: I move amendment No, NORMALIZED: ImoveamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ImoveamendmentNo
# LINE: 45: In page 11, between lines 11 and 12, to insert the following: “Report 7, NORMALIZED: 45:Inpage11,betweenlines11and12,toinsertthefollowing:“Report7
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 45:Inpage11,betweenlines11and12,toinsertthefollowing:“Report7
# LINE: The Minister shall, within three years of the passing of this Act, lay a report before both Houses of the Oireachtas outlining a sectoral analysis with respect to the informa­ tion published under section 2 and further recommendations based upon such analysis in terms of reducing the gender pay gap.”, NORMALIZED: TheMinistershall,withinthreeyearsofthepassingofthisAct,layareportbeforebothHousesoftheOireachtasoutliningasectoralanalysiswithrespecttotheinforma­tionpublishedundersection2andfurtherrecommendationsbaseduponsuchanalysisintermsofreducingthegenderpaygap.”
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheMinistershall,withinthreeyearsofthepassingofthisAct,layareportbeforebothHousesoftheOireachtasoutliningasectoralanalysiswithrespecttotheinforma­tionpublishedundersection2andfurtherrecommendationsbaseduponsuchanalysisintermsofreducingthegenderpaygap.”
# LINE:  21 June 2021 371 Amendment put and declared lost, NORMALIZED: 21June2021371Amendmentputanddeclaredlost
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 21June2021371Amendmentputanddeclaredlost
# LINE: SECTION 7, NORMALIZED: SECTION7
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: SECTION7
# LINE: I move amendment No, NORMALIZED: ImoveamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ImoveamendmentNo
# LINE: 46: In page 11, to delete lines 19 to 22 and substitute the following: “(1) This Act shall come into operation three months after it has been passed by both Houses of the Oireachtas or a prior date which the Minister may appoint by order.”., NORMALIZED: 46:Inpage11,todeletelines19to22andsubstitutethefollowing:“(1)ThisActshallcomeintooperationthreemonthsafterithasbeenpassedbybothHousesoftheOireachtasorapriordatewhichtheMinistermayappointbyorder.”.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 46:Inpage11,todeletelines19to22andsubstitutethefollowing:“(1)ThisActshallcomeintooperationthreemonthsafterithasbeenpassedbybothHousesoftheOireachtasorapriordatewhichtheMinistermayappointbyorder.”.
# LINE: Does Senator Higgins wish to speak to the amendment?, NORMALIZED: DoesSenatorHigginswishtospeaktotheamendment?
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: DoesSenatorHigginswishtospeaktotheamendment?
# LINE: The Minister indicated his wish for speedy passage and implementation of the Bill, NORMALIZED: TheMinisterindicatedhiswishforspeedypassageandimplementationoftheBill
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheMinisterindicatedhiswishforspeedypassageandimplementationoftheBill
# LINE:  In that context, I am happy to withdraw the amendment, NORMALIZED: Inthatcontext,Iamhappytowithdrawtheamendment
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Inthatcontext,Iamhappytowithdrawtheamendment
# LINE: Amendment, by leave, withdrawn, NORMALIZED: Amendment,byleave,withdrawn
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Amendment,byleave,withdrawn
# LINE: Section 7 agreed to., NORMALIZED: Section7agreedto.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Section7agreedto.
# LINE: Amendment No, NORMALIZED: AmendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: AmendmentNo
# LINE: 47 in the names of Senators Warfield, Boylan, Ó Donnghaile and Gavan is out of order as it is consequential on amendment No, NORMALIZED: 47inthenamesofSenatorsWarfield,Boylan,ÓDonnghaileandGavanisoutoforderasitisconsequentialonamendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 47inthenamesofSenatorsWarfield,Boylan,ÓDonnghaileandGavanisoutoforderasitisconsequentialonamendmentNo
# LINE: 41, NORMALIZED: 41
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 41
# LINE: Amendment No, NORMALIZED: AmendmentNo
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: AmendmentNo
# LINE: 47 not moved, NORMALIZED: 47notmoved
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: 47notmoved
# LINE: Title agreed to, NORMALIZED: Titleagreedto
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Titleagreedto
# LINE: Bill reported with amendments., NORMALIZED: Billreportedwithamendments.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Billreportedwithamendments.
# LINE: When is it proposed to take Report Stage?, NORMALIZED: WhenisitproposedtotakeReportStage?
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: WhenisitproposedtotakeReportStage?
# LINE: On Friday, 25 June 2021., NORMALIZED: OnFriday,25June2021.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: OnFriday,25June2021.
# LINE: Is that agreed?  Agreed, NORMALIZED: Isthatagreed?Agreed
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Isthatagreed?Agreed
# LINE: Report Stage ordered for Friday, 25 June 2021., NORMALIZED: ReportStageorderedforFriday,25June2021.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: ReportStageorderedforFriday,25June2021.
# LINE: When is it proposed to sit again?, NORMALIZED: Whenisitproposedtositagain?
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Whenisitproposedtositagain?
# LINE: Tomorrow morning at 9 a.m, NORMALIZED: Tomorrowmorningat9a.m
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: Tomorrowmorningat9a.m
# LINE: in the convention centre, NORMALIZED: intheconventioncentre
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: intheconventioncentre
# LINE: The Seanad adjourned at 9.07 p.m until 9 a.m, NORMALIZED: TheSeanadadjournedat9.07p.muntil9a.m
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: TheSeanadadjournedat9.07p.muntil9a.m
# LINE: on Tuesday, 22 June 2021., NORMALIZED: onTuesday,22June2021.
# NORMALIZED TOPIC: PlanningandDevelopment(SolarPanelsforPublicBuildings,Schools,HomesandOtherPremises)(Amend, NORMALIZED: onTuesday,22June2021.
#                                        file_name  \
# 0    Seanad Éireann debate - Monday, 21 Jun 2021
# 1    Seanad Éireann debate - Monday, 21 Jun 2021
# 2    Seanad Éireann debate - Monday, 21 Jun 2021
# 3    Seanad Éireann debate - Monday, 21 Jun 2021
# 4    Seanad Éireann debate - Monday, 21 Jun 2021
# ..                                           ...
# 297  Seanad Éireann debate - Monday, 21 Jun 2021
# 298  Seanad Éireann debate - Monday, 21 Jun 2021
# 299  Seanad Éireann debate - Monday, 21 Jun 2021
# 300  Seanad Éireann debate - Monday, 21 Jun 2021
# 301  Seanad Éireann debate - Monday, 21 Jun 2021
#
#                                                  Topic  \
# 0                 Gnó an tSeanaid - Business of Seanad
# 1                                     Travel Documents
# 2                                     Travel Documents
# 3                                     Travel Documents
# 4                                 School Accommodation
# ..                                                 ...
# 297  Gender Pay Gap Information Bill 2019: Committe...
# 298  Gender Pay Gap Information Bill 2019: Committe...
# 299  Gender Pay Gap Information Bill 2019: Committe...
# 300  Gender Pay Gap Information Bill 2019: Committe...
# 301  Gender Pay Gap Information Bill 2019: Committe...
#
#                          Speaker  \
# 0               An Cathaoirleach
# 1        Senator  Regina Doherty
# 2        Senator  Regina Doherty
# 3           Deputy  Ossian Smyth
# 4             Senator  Seán Kyne
# ..                           ...
# 297       An Leas-Chathaoirleach
# 298  Senator  Mary Seery Kearney
# 299       An Leas-Chathaoirleach
# 300       An Leas-Chathaoirleach
# 301  Senator  Mary Seery Kearney
#
#                                             Exact Text Category
# 0    I have received notice from Senator Regina Doh...     test
# 1    I thank the Minister of State for his attendan...     test
# 2    I thank the Minister of State.  Respectfully, ...     test
# 3    First, the Senator asked how people apply.  In...     test
# 4    I thank the Cathaoirleach’s office for choosin...     test
# ..                                                 ...      ...
# 297          When is it proposed to take Report Stage?     test
# 298                           On Friday, 25 June 2021.     test
# 299  Is that agreed?  Agreed. Report Stage ordered ...     test
# 300                  When is it proposed to sit again?     test
# 301  Tomorrow morning at 9 a.m. in the convention c...     test
#
# [302 rows x 5 columns]

# %%
distinct_topics_updated_df = updated_df['Topic'].unique()
print(distinct_topics_updated_df)
# Out:
# ['Gnó an tSeanaid - Business of Seanad' 'Travel Documents'
#  'School Accommodation' 'Job Creation' 'Pharmacy Services'
#  'Employment Support Services' 'Defence Forces'
#  'An tOrd Gnó - Order of Business'
#  'Eleventh Report of Committee on Parliamentary Privileges and Oversight: Motion'
#  'Climate Action and Low Carbon Development (Amendment) Bill 2021: Second Stage'
#  'Aviation Sector: Statements'
#  'Gender Pay Gap Information Bill 2019: Committee Stage']

# %%
def save_to_excel(df, excel_path):
    df.to_excel(excel_path, index=False)

excel_path_separate = r'C:\Users\0132499s\Documents\Documents\Transcript\test\test2.xlsx'

save_to_excel(updated_df, excel_path_separate)

# %% [markdown]
# ### Merging the extracted dataframe with the year category dataframe, so that each of the Speaker and Texts is now categorised in two-year intervals.

# %%
f = 'Dáil Éireann debate - Thursday, 31 Mar 2022'
matching_row = files_with_year.loc[files_with_year['file_name'] == f.lower()]
print(matching_row)
# Out:
#                                      file_name   ID  Year Sliding_year
# 0  dáil éireann debate - thursday, 31 mar 2022  512  2022    2022-2024

# %%
final_df = merge_text_year(df_with_text, files_with_year)
print(final_df)
# Out:
#                                          file_name   ID  Year Sliding_year  \
# 0     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 1     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 2     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 3     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 4     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# ...                                            ...  ...   ...          ...
# 1867  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1868  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1869  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1870  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1871  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
#
#                                                   Topic  \
# 0                                      Company Closures
# 1     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 2     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 3     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 4     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# ...                                                 ...
# 1867                      Message from Select Committee
# 1868     Neutrality: Motion (Resumed) [Private Members]
# 1869  Horse and Greyhound Racing Fund Regulations 20...
# 1870  Horse and Greyhound Racing Fund Regulations 20...
# 1871  Horse and Greyhound Racing Fund Regulations 20...
#
#                                                 Speaker  \
# 0                                  Deputy Dara Calleary
# 1                                  Deputy Dara Calleary
# 2                                    Deputy Gerald Nash
# 3                                  Deputy Dara Calleary
# 4                                    Deputy Gerald Nash
# ...                                                 ...
# 1867                           An Leas-Cheann Comhairle
# 1868                           An Leas-Cheann Comhairle
# 1869                           An Leas-Cheann Comhairle
# 1870  Minister of State at the Department of the Tao...
# 1871         Minister for Transport (Deputy Eamon Ryan)
#
#                                              Exact Text Category
# 0     It is nearly six weeks since the overnight tak...     test
# 1     As the Minister of State said, the liquidators...     test
# 2     Directors have responsibilities to their emplo...     test
# 3     Under section 224 of the Companies Act, direct...     test
# 4     I referred to that matter in referring to the ...     test
# ...                                                 ...      ...
# 1867  The Select Committee on Social Protection, Com...     test
# 1868  I must now deal with a postponed division rela...     test
# 1869  I must now deal with a postponed division rela...     test
# 1870  We had intended to move the Estimate for Vote ...     test
# 1871  I move the following Supplementary Estimates: ...     test
#
# [1872 rows x 8 columns]

# %%
distinct_topic_count = final_df.groupby('Topic').size().reset_index(name = 'Counts')
print(distinct_topic_count)
# Out:
#                                                 Topic  Counts
# 0                                Agriculture Industry       5
# 1                     An tOrd Gnó - Order of Business       3
# 2                           Apprenticeship Programmes       1
# 3                         Aviation Sector: Statements       2
# 4                                       Beef Industry       2
# ..                                                ...     ...
# 79                                   Travel Documents       1
# 80                         Visit of Kenyan Delegation       1
# 81             Women’s Health Action Plan: Statements       1
# 82                                Youth Work Projects       4
# 83  Ábhair Shaincheisteanna Tráthúla - Topical Iss...       2
#
# [84 rows x 2 columns]

# %% [markdown]
# ### Data Pre-Processing and Cleaning steps applied on the final_df, which has Speaker and Text details categorised by years.

# %%
# Remove Header-Footer
final_df['Text'] = final_df['Exact Text'].apply(lambda x: remove_header_footer(x, headers))
final_df['Exact Text'] = final_df['Exact Text'].apply(lambda x: remove_header_footer(x, headers))
final_df['Exact Text'] = final_df['Exact Text'].str.replace('\u00A0', ' ', regex=False)

# Remove lines with less than 5 words
final_df = remove_line_less_than_five(final_df)

# Remove stop words
final_df['Text'] = final_df['Text'].apply(remove_stop_words)

# Remove
final_df['Text'] = final_df['Text'].apply(extract_grammer)

# Remove speaker names from the final speeches
final_df = remove_speaker_words(final_df)

final_df['Text'] = final_df['Text'].apply(remove_special_char)

# Remove extra spaces from the Speaker names
final_df['Speaker'] = final_df['Speaker'].apply(remove_extra_spaces_and_numbers)
final_df['Text'] = final_df['Text'].apply(remove_extra_spaces_and_numbers)
# Out:
# All speaker words :{'Comhairle', 'Sherlock', 'Professor', 'Frankie', 'Patrick', 'Durkan)', 'Corcoran', 'Donnghaile', 'Browne', 'Paul', 'Simon', 'Andrew', 'Ross', 'Children', 'An Ceann Comhairle', 'Matt', 'Reilly', 'Lochlainn', 'General', 'Higgins', 'O’Brien)', 'Richard', 'Seery', 'Denise', 'Keating)', 'Whitmore', 'Robbie', 'McEntee)', 'Buttimer)', 'Environment,', 'Shane', 'Mary', 'Ríordáin', 'Fleming', 'Berry', 'Sharon', 'Farrell', 'McEntee', 'The Tánaiste', 'Troy)', 'Communications', 'Chairman', 'Doyle', 'Smith', 'Butler)', 'Dolan)', 'Ruairí', 'Crowe', 'McGahon)', 'Cannon', 'Marine', 'Ferris', 'Brendan', 'Josepha', 'Neville', 'Protection', 'Warfield', 'Louise', 'Fergus', 'Timmy', 'for', 'Cathal', 'Gallagher', 'McLellan', 'Pa', 'Currie', 'Bacik', 'Joan', 'Smyth', 'McGreehan', 'Sorca', 'Chairperson', 'Tom', 'O’Gorman', 'Gníomhach', 'Paschal', 'Gino', 'Jennifer', 'Vincent', 'Mark', 'Health', 'Damien', 'Mitchell', 'Bernard', 'Ahearn', 'Sean', 'Sport', 'Horkan', 'Róisín', 'Garvey', 'Cullinane', 'Twomey)', 'Healy-Rae', 'Thomas', 'Lynn', 'Claire', 'Jerry', 'O’Sullivan)', 'Leddin', 'Ciarán', 'Wallace', 'Gerry', 'O’Connor', 'Senator', 'Norris', 'Helen', 'Harkin', 'Ivana', 'Education', 'Dolan', 'Andrews', 'Murnane', 'Brian', 'Seán', 'Coveney', 'Niall', 'Maureen', 'Alan', 'Shortall', 'Cassells', 'Laoghaire', 'Joe', 'Doherty', 'Snodaigh', 'Dara', 'Charlie', 'Clerk', 'Dr.', 'Minister', 'Kelly', 'McHugh', 'Eamon', 'O’Dea', 'Coveney)', 'Carthy', 'Costello', 'Aodhán', 'Fitzpatrick', 'Feighan', 'Garret', 'Denis', 'Jan', 'McGrath', 'Donohoe', 'Kehoe', 'Deputy', 'Conway', 'Bruton', 'Colreavy', 'Noel', 'An Leas-Cheann Comhairle', 'Gabrielle', 'Connolly', 'Fearghaíl', 'Ceann', 'Foreign', 'O’Reilly', 'Hackett)', 'Carroll', 'Réada', 'Ó', 'Noonan', 'Liam', 'Vice', 'Kenny', 'Peter', 'Mattie', 'Troy', 'Ryan)', 'Bruton)', 'Cowen', 'An', 'McDonald', 'Carrigy', 'Leas-Chathaoirleach', 'Justice(Deputy', 'Ring)', 'Snodaigh)', 'Audit', 'McAuliffe', 'Shanahan', 'Madigan', 'Burke', 'Cairns', 'James', 'Mulherin', 'Youth', 'Dan', 'Robert', 'The', 'Agriculture,', 'McFadden', 'Pauline', 'Maria', 'Donnelly)', 'English', 'Ray', 'and', 'Defence', 'J.', 'Fleming)', 'Lowry', 'Marcella', 'Stephen', 'Pearse', 'Ryan', 'Moynihan', '(Senator', 'Gerald', 'Jobs,', 'Donnelly', 'Pádraig', 'Grealish', 'Kennedy', 'Boyd', 'David', 'Adams', 'Paddy', 'Peadar', 'Cuív', 'Marc', 'Erin', 'Hildegarde', 'Darren', 'Acting Chairperson', 'Dessie', 'Phelan', 'O’Brien', 'Coonan', 'Willie', 'Social', 'Lou', 'Noonan)', 'Carey', 'Transport,', 'Affairs', 'Catherine', 'Comptroller', 'Co-Chairman', 'Brady', 'Mick', 'Climate', 'Brophy)', 'Cathaoirleach', '(Deputy', 'Murphy', 'Pippa', 'State', 'at', 'Alice-Mary', 'Halligan', 'Trade', 'Pringle', 'Madigan)', 'Kyne', 'The Taoiseach', 'Taoiseach', 'Department', 'Micheál', 'Clare', 'McGahon', 'Taoiseach(Deputy', 'Browne)', 'Fintan', 'Ellis', 'Boyhan', 'Collins', 'Verona', 'Lynch', 'O’Mahony', 'Ann', 'Sandra', 'Deputies', 'Barrett', 'O’Rourke', 'Acting', 'Emer', 'Gilmore', 'Mac', 'Craughwell', 'Fitzmaurice', 'Nash', 'Food', 'Buttimer', 'Tim', 'McConalogue)', 'Ged', 'An Leas-Chathaoirleach', 'Michelle', 'Clarke', 'Innovation', 'Durkan', 'Boylan', 'Martin', 'MacNeill', 'Ardagh', 'Gavan', 'Kearney', 'Acting Chairman', 'Lisa', 'Calleary', 'Gerard', 'Donohoe)', 'Donnchadh', 'Byrne', 'Leas-Cheann', 'P.', 'Victor', 'Ruth', 'Holly', 'Ms', 'Skills', 'Reilly)', 'Lombard', 'Ward', 'Chambers', 'O’Loughlin)', 'Butler', 'Naughton)', 'Harrington', 'Aengus', 'Tully', 'Derek', 'Enterprise', 'O’Donoghue', 'Duncan', 'Lynch)', 'Dooley', 'Stanton', 'Aisling', 'O’Sullivan', 'Ollie', 'MacSharry', 'Transport', 'Tóibín', 'Charles', 'Terence', 'Colm', 'the', 'Wall', 'Coppinger', 'Barry', 'Finance', 'Kathleen', 'John', 'Seamus', 'Kerrane', 'McNamara', 'Tourism', 'Stanley', 'McDowell', 'of', 'Murchú', 'Patricia', 'O’Connor)', 'Brophy', 'Bríd', 'Éamon', 'Feighan)', 'MacNeill)', 'Daly', 'Christopher', 'Nash)', 'McGuinness', 'Canney', 'Chris', 'McConalogue', 'Mr.', 'Keogan', 'Ossian', 'E ...

# %%
final_df = final_df[final_df['Topic'].notna()
&
final_df['Topic'].str.strip().astype(bool)]

# %%
distinct_topics = final_df['Topic'].unique()
print(distinct_topics)
# Out:
# ['Company Closures'
#  'Child Care (Guardian Ad Litem) Bill 2015: First Stage 60 5072015Y 00100Events at Ballymurphy in 1971 and Legacy Issues: Motion'
#  'Company Law' 'Employment Rights' 'IDA Supports' 'Trade Agreements'
#  'Enterprise Support Schemes' 'Departmental Communications'
#  'Construction Contracts'
#  'Defence (Amendment) Bill 2015 [Seanad]: Second Stage'
#  'Defence (Amendment) Bill 2015 [Seanad]: Committee and Remaining Stages'
#  'Leaders’ Questions' 'Order of Business' 'Northern Ireland: Statements'
#  'Message from Seanad' 'Tax Code' 'Apprenticeship Programmes'
#  'Teaching Qualifications' 'Cycling Facilities Funding'
#  'Climate Action and Low Carbon Development Bill 2015: Report and Final Stages 120 2015DDD 00050Children (Amendment) Bill 2015 [Seanad]: Order for Report Stage'
#  'Children (Amendment) Bill 2015 [Seanad]: Report and Final Stages 128 0Petroleum (Exploration and Extraction) Safety Bill 2015 [Seanad]: Second Stage'
#  'Social Services and Support: Motion (Resumed) [Private Members]'
#  'Gnó an tSeanaid - Business of Seanad' 'Travel Documents'
#  'Planning and Development (Solar Panels for Public Buildings, Schools, Homes and Other Premises) (Amend ment) Bill 2021: First Stage'
#  'School Accommodation' 'Job Creation' 'Pharmacy Services'
#  'Employment Support Services' 'Defence Forces'
#  'An tOrd Gnó - Order of Business'
#  'Eleventh Report of Committee on Parliamentary Privileges and Oversight: Motion'
#  'Climate Action and Low Carbon Development (Amendment) Bill 2021: Second Stage'
#  'Aviation Sector: Statements' 'Health Service Executive'
#  'Circular Economy, Waste Management (Amendment) and Minerals Development (Amendment) Bill 2022: Sec ond Stage (Resumed)'
#  'National Maternity Hospital' 'Health Services Staff' 'Covid-19 Pandemic'
#  'Disability Services' 'Health Services' 'Hospital Facilities'
#  'Departmental Policies' 'Home Help Service' 'Hospital Services'
#  'Message from Select Committee' 'Departmental Funding'
#  'Regulatory Bodies' 'Timber Supply' 'Horticulture Sector'
#  'Agriculture Industry' 'Fisheries Protection' 'Beef Industry'
#  'Harbours and Piers' 'Inshore Fisheries' 'Renewable Energy Generation'
#  'Ceisteanna ó Cheannairí - Leaders’ Questions'
#  'Ceisteanna ar Reachtaíocht a Gealladh - Questions on Promised Legislation'
#  'Employment Equality (Abolition of Mandatory Retirement Age) Bill 2022: First Stage'
#  'Women’s Health Action Plan: Statements'
#  'Ábhair Shaincheisteanna Tráthúla - Topical Issue Matters'
#  'School Transport' 'Health Strategies' 'Medicinal Products'
#  'Management of Estates' 'National Maternity Hospital: Statements'
#  'Childcare Services' 'Schools Building Projects' 'Youth Work Projects'
#  'Capital Supply Service and Purpose Report Bill 2023: Second Stage [Private Members]'
#  'Estimates for Public Services 2023: Messages from Select Committees'
# ### Append the Topics at the starting of the Exact Text string, in a separate column.

# %%
def append_topic(row):
    return f"'{row['Topic'].lower()}' {row['Exact Text']}"

final_df['Exact Text For Combined'] = final_df['Exact Text']
final_df['Exact Text'] = final_df.apply(append_topic, axis = 1)

# %%
print(final_df)
# Out:
#                                          file_name   ID  Year Sliding_year  \
# 0     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 1     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 2     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 3     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# 4     dáil éireann debate - wednesday, 15 jul 2015   59  2015    2014-2016
# ...                                            ...  ...   ...          ...
# 1867  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1868  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1869  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1870  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
# 1871  dáil éireann debate - wednesday, 29 nov 2023  669  2023    2022-2024
#
#                                                   Topic  \
# 0                                      Company Closures
# 1     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 2     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 3     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# 4     Child Care (Guardian Ad Litem) Bill 2015: Firs...
# ...                                                 ...
# 1867                      Message from Select Committee
# 1868     Neutrality: Motion (Resumed) [Private Members]
# 1869  Horse and Greyhound Racing Fund Regulations 20...
# 1870  Horse and Greyhound Racing Fund Regulations 20...
# 1871  Horse and Greyhound Racing Fund Regulations 20...
#
#                                                 Speaker  \
# 0                                  Deputy Dara Calleary
# 1                                  Deputy Dara Calleary
# 2                                    Deputy Gerald Nash
# 3                                  Deputy Dara Calleary
# 4                                    Deputy Gerald Nash
# ...                                                 ...
# 1867                           An Leas-Cheann Comhairle
# 1868                           An Leas-Cheann Comhairle
# 1869                           An Leas-Cheann Comhairle
# 1870  Minister of State at the Department of the Tao...
# 1871         Minister for Transport (Deputy Eamon Ryan)
#
#                                              Exact Text Category  \
# 0     'company closures' It is nearly six weeks sinc...     test
# 1     'child care (guardian ad litem) bill 2015: fir...     test
# 2     'child care (guardian ad litem) bill 2015: fir...     test
# 3     'child care (guardian ad litem) bill 2015: fir...     test
# 4     'child care (guardian ad litem) bill 2015: fir...     test
# ...                                                 ...      ...
# 1867  'message from select committee' The Select Com...     test
# 1868  'neutrality: motion (resumed) [private members...     test
# 1869  'horse and greyhound racing fund regulations 2...     test
# 1870  'horse and greyhound racing fund regulations 2...     test
# 1871  'horse and greyhound racing fund regulations 2...     test
#
#                                                    Text  \
# 0     six weeks take out Clerys interests concern bu...
# 1     liquidors investigion committee investigion fi...
# 2     Directors responsibilities employees case duti...
# 3     section Companies Act directors must interests...
# 4     mter committee inspection committee case credi...
# ...                                                 ...
# 1867  Select Committee Community Rural Development I...
# 1868  must division motion neutrality Tuesday questi...
# 1869  must division motion horse greyhound funding W...
# 1870  move Estime Vote committee considerion Vote Es...
# 1871  move Estimes Vote Supplementary Estime sum def...
#
#                                 Exact Text For Combined
# 0     It is nearly six weeks since the overnight tak...
# 1     As the Minister of State said, the liquidators...
# 2     Directors have responsibilities to their emplo...
# 3     Under section 224 of the Companies Act, direct...
# 4     I referred to that matter in referring to the ...
# ...                                                 ...
# 1867  The Select Committee on Social Protection, Com...
# 1868  I must now deal with a postponed division rela...
# 1869  I must now deal with a postponed division rela...
# 1870  We had intended to move the Estimate for Vote ...
# 1871  I move the following Supplementary Estimates: ...
#
# [1512 rows x 10 columns]

# %% [markdown]
# ### Export as Excel
# #### Saving both dataframes with separate Speaker Texts and with grouped by Speaker and Year Interval Texts as excel files. Can be skipped since the complete 'Text' did not fit in the excel, more than half of the 'Text' got cut off.

# %%
def save_to_excel(df, excel_path):
    df.to_excel(excel_path, index=False)

excel_path_separate = r'C:\Users\0132499s\Documents\Documents\Transcript\test\SlidingYear_Separate_Speaker.xlsx'

save_to_excel(final_df, excel_path_separate)

# %% [markdown]
# ### Update: 15.10.2024
#
# #### Pillar I of the technical architecture does not require grouped texts, since we will be extracting the exact texts said by the stakeholder. So inserting each text individually for each dialogue.
#
# The function will check if there is already a records available for same 'Speaker', 'File Name' and 'Exact Text', the insert will only be done if no such record is available in the collection.

# %%
def store_exact_df_in_mongodb(df, db_url, db_name, collection_name):
    client = MongoClient(db_url)
    db = client[db_name]
    collection = db[collection_name]
    inserted_count = 0
    
    for index, row in df.iterrows():
        query = {
            "Speaker": row["Speaker"],
            "file_name": row["file_name"],
            "Exact Text": row["Exact Text"],
            "Exact Text For Combined": row["Exact Text For Combined"]
        }
        
        # Check if the document already exists
        if collection.count_documents(query) == 0:
            record = row.to_dict()
            collection.insert_one(record)
            inserted_count += 1
    
    print(f'Number of records inserted: {inserted_count}')

# %%
store_exact_df_in_mongodb(final_df, db_url, 'transcripts', 'P1_speaker_speech')
# Out:
# Number of records inserted: 93292

# %% [markdown]
# ### Store the extracted topics in the 'keywords' collection.

# %%
def insert_topics_to_mongodb(folder_path, db_name, collection_name):
    # Connect to MongoDB
    client = MongoClient('mongodb://localhost:27017/')
    db = client[db_name]
    collection = db[collection_name]
    
    # Iterate through all PDF files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf'):
            pdf_path = os.path.join(folder_path, filename)
            final_topics, _ = extract_topics_from_index(pdf_path)
            
            # Convert topics to lowercase and insert into MongoDB if not already present
            for topic in final_topics:
                topic_lower = topic.lower()
                if not collection.find_one({'keywords': topic_lower}):
                    collection.insert_one({'keywords': topic_lower})

folder_path = r'C:\Users\0132499s\Documents\Documents\Transcripts - Miscellanous\Dail Eireann'
db_name = 'foodsystems'
collection_name = 'keywords'
insert_topics_to_mongodb(folder_path, db_name, collection_name)

# %% [markdown]
# ### To check if any of the rows has more than 32,000 characters(maximum limit for an excel cell) for any Text column.

# %%
long_text_row = final_df[final_df['Text'].str.len() > 32000]
if not long_text_row.empty:
    print("Row with more than 32000 characters found: ")
    print(long_text_row)
else:
    print("No rows with more than 32000 characters")
# Out:
# No rows with more than 32000 characters
